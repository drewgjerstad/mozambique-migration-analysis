# %% [markdown]
# # Data Analysis
# This is a starter notebook for loading the IPUMS data and perform analyses.

# %%
# Load Dependencies
from pathlib import Path
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# Load Custom Scripts
from src.utils.ipums_extract import (
    get_ipums_data,
    load_ipums_from_pkl,
)

# %% [markdown]
# ## Load IPUMS Dataset

# %%
# Define Parameters (do not push your API key to VCS)
API_KEY = "59cba10d8a5da536fc06b59de2965f8fa8d8478dabad9751c577a909"
DOWNLOAD_DIR = Path(r"data")
PKL_EXPORT = True
PKL_PATH = Path(r"data/ipums_extract.pkl")

collection = "ipumsi"
description = "data mining mozambique project"
samples = ["mz1997a", "mz2007a", "mz2017a"]

# %%
# Define Variables
variables = [
    # Tech Households
    "PERSONS",
    # Group Quarters
    "GQ", "GQTYPE", "UNREL",
    # Global Geography
    "URBAN", "POPDENSGEO1", "POPDENSGEO2",
    # National Geography
    "GEO1_MZ", "GEO2_MZ",
    # Household Economic
    "OWNERSHIP",
    # Utilities
    "ELECTRIC", "WATSUP", "PHONE",
    # Appliances
    "AUTOS", "MOTORCYCLE", "BIKE", "COMPUTER", "TV", "RADIO",
    # Dwelling Characteristics
    "ROOMS", "BEDROOMS", "TOILET", "FLOOR", "WALL", "ROOF",
    # Constructed Household
    "HHTYPE", "NFAMS", "NCOUPLES", "NMOTHERS", "NFATHERS",
    # Constructed Family
    "FAMSIZE", "NCHILD", "NCHLT5", "ELDCH", "YNGCH",
    # Demographic
    "RELATE", "AGE", "SEX", "MARST", "CONSENS", 
    # Fertility and Mortality
    "CHBORN", "CHSURV", "CHBORNF", "CHBORNM", "CHSURVF", "CHSURVM", "BIRTHSLYR",
    "BIRTHSURV", "MORTMOT", "MORTFAT",
    # Navity and Birthplace
    "NATIVITY", "CITIZEN", "NATION", "BPL1_MZ", "BPL2_MZ",
    # Ethnicity and Language
    "RELIGION", "RACE", "SPEAKPORT", "LANGMZ", "MTONGMZ", 
    # Education
    "SCHOOL", "LIT", "EDATTAIN",
    # Work
    "EMPSTAT", "LABFORCE", "EMPSECT",
    # Occupation, Industry
    "OCCISCO", "INDGEN",
    # Global Migration - Not giving us any other migration variables,
    # as they would likely be too correlated and uninteresting (AH)
    "MIGRATE1", "MIGRATE5", 
    # Disability
    "DISABLED", "DISEMP", "DISBLND", "DISDEAF", "DISMUTE", "DISLOWR", "DISUPPR",
    "DISMNTL", "DISORIG"
]

# %%
# Get IPUMS Data
ipums_df = get_ipums_data(
    collection=collection,
    description=description,
    samples=samples,
    variables=variables,
    api_key=API_KEY,
    download_dir=DOWNLOAD_DIR,
    pkl_export=PKL_EXPORT,
    pkl_path=PKL_PATH
)
# Out:
# Extract submitted to IPUMS. Extract ID: 2.
# Waiting for extract to finish processing on IPUMS server...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[33], line 2
#       1 # Get IPUMS Data
# ----> 2 ipums_df = get_ipums_data(
#       3     collection=collection,
#       4     description=description,
#       5     samples=samples,
#       6     variables=variables,
#       7     api_key=API_KEY,
#       8     download_dir=DOWNLOAD_DIR,
#       9     pkl_export=PKL_EXPORT,
#      10     pkl_path=PKL_PATH
#      11 )
#
# File c:\Users\Hasan\OneDrive\Desktop\csci5523\umn-fall2025-csci5523-project\src\utils\ipums_extract.py:74, in get_ipums_data(collection, description, samples, variables, api_key, download_dir, pkl_export, pkl_path)
#      72 # Wait for Extract
#      73 print("Waiting for extract to finish processing on IPUMS server...")
# ---> 74 ipums.wait_for_extract(extract)
#      76 # Download Extract
#      77 print(f"Downloading extract to {download_dir} ...")
#
# File c:\Users\Hasan\OneDrive\Desktop\csci5523\umn-fall2025-csci5523-project\venv\Lib\site-packages\ipumspy\api\core.py:409, in IpumsApiClient.wait_for_extract(self, extract, collection, inital_wait_time, max_wait_time, timeout)
#     405     raise IpumsNotFound(
#     406         f"There is no IPUMS extract with extract number {extract_id} in collection {collection}"
#     407     )
#     408 elif status != "completed":
# --> 409     time.sleep(wait_time)
#     410     total_time += wait_time
#     411     wait_time = min(wait_time * 2, max_wait_time)
#
# KeyboardInterrupt:

# %%
# Load from PKL
ipums_df_pkl = load_ipums_from_pkl(PKL_PATH)

# %%
# Remove Migration NIUS and unknown
mig1_data = ipums_df_pkl[~ipums_df_pkl['MIGRATE1'].isin(['NIU (not in universe)', 'Unknown/missing'])].copy()
mig5_data = ipums_df_pkl[~ipums_df_pkl['MIGRATE5'].isin(['NIU (not in universe)', 'Unknown/missing'])].copy()

# Binarize 
map_vals = {'Same major, same minor administrative unit':0,
            'Same major administrative unit':0,
            'Same major, different minor administrative unit':0,
            'Different major administrative unit':1,
            'Abroad':0}
mig1_data['mig_provincial'] = mig1_data['MIGRATE1'].map(map_vals)
mig5_data['mig_provincial'] = mig5_data['MIGRATE5'].map(map_vals)

# Remove original migrate vars
mig1_data = mig1_data.drop(['MIGRATE1', 'MIGRATE5'], axis=1)
mig5_data = mig5_data.drop(['MIGRATE1', 'MIGRATE5'], axis=1)

# %%
print(mig1_data['mig_provincial'].value_counts(dropna=False))
print(mig5_data['mig_provincial'].value_counts(dropna=False))
# Out:
# mig_provincial
# 0    5879434
# 1      50095
# Name: count, dtype: int64
# mig_provincial
# 0    4847198
# 1     127371
# Name: count, dtype: int64

# %% [markdown]
# ## Data Analysis

# %% [markdown]
# ### Value Counts for Each Set
# In this section, we print out the value counts for each column in the sets. This
# will allow us to identify useless (i.e., all the same value) or unique (i.e.,
# will not generalize well) columns for removal.

# %%
for col in mig1_data.columns:
    print(mig1_data[col].value_counts())
    print('-'*30)
# Out:
# COUNTRY
# Mozambique    5929529
# Name: count, dtype: int64
# ------------------------------
# YEAR
# 2017    2545554
# 2007    1931544
# 1997    1452431
# Name: count, dtype: int64
# ------------------------------
# SAMPLE
# Mozambique 2017    2545554
# Mozambique 2007    1931544
# Mozambique 1997    1452431
# Name: count, dtype: int64
# ------------------------------
# SERIAL
# 26886000     58
# 342270000    56
# 261828000    52
# 442445000    50
# 261007000    50
#              ..
# 572222000     1
# 515565000     1
# 614356000     1
# 614348000     1
# 478224000     1
# Name: count, Length: 612509, dtype: Int64
# ------------------------------
# PERSONS
# 6     979624
# 5     956894
# 4     888129
# 3     686787
# 7     641334
# 8     468220
# 2     398578
# 9     314093
# 10    152814
# 1     140392
# 11     99157
# 12     67139
# 13     39168
# 14     26461
# 15     18694
# 16     13858
# 17      9780
# 18      7793
# 19      4135
# 20      3105
# 21      2806
# 22      2249
# 24      1468
# 23      1098
# 25      1067
# 26       769
# 27       696
# 28       555
# 30       340
# 29       320
# 31       313
# 35       296
# 32       213
# 36       198
# 39       191
# 34       150
# 44       123
# 33        94
# 47        92
# 45        90
# 37        73
# 50        48
# 48        48
# 41        40
# 38        37
# Name: count, dtype: Int64
# ------------------------------
# HHWT
# 10.00    5892542
# 10.01      17008
# 9.99       15087
# 10.02       2567
# 0.00        2325
# Name: count, dtype: int64
# ------------------------------
# GQ
# Households                                            5921521
# Other group quarters                                     2430
# 1-person unit created by splitting large household       2325
# Institutions                                             1875
# Unknown/group quarters not identified                    1378
# Name: count, dtype: int64
# ------------------------------
# GQTYPE
# NIU (not in universe)                                                           3375967
# 1-person unit created by splitting large household                                 2325
# Other group quarters                                                               1443
# Unknown                                                                            1378
# Floating population                                                                 844
# Boarding school or student housing                                                  716
# Military or police institution                                                      534
# Hospital, nursing home, hospice, or instutions for persons with disabilities        300
# Prisons, reformatories, or correctional institutions                                168
# Religious institution, monastery, seminary, or convent                              157
# Hotel, pension, lodging, or boarding house                                          143
# Name: count, dtype: int64
# ------------------------------
# UNREL
# 0     5727870
# 1      159823
# 2       24683
# 3        7682
# 4        3477
# 9+       2220
# 5        1665
# 6         981
# 7         644
# 8         484
# Name: count, dtype: int64
# ------------------------------
# URBAN
# Rural      4100523
# Urban      1828805
# Unknown        201
# Name: count, dtype: int64
# ------------------------------
# POPDENSGEO1
# 70.21      516948
# 48.64      469693
# 51.82      381628
# 37.83      367474
# 28.44      277828
# 38.61      272480
# 25.38      242277
# 29.02      215269
# 32.01      208824
# 81.62      179204
# 30.12      175302
# 17.81      169543
# 14.03      162806
# 24.33      157669
# 20.92      154763
# 21.13      139471
# 23.34      134197
# 18.44      132638
# 19.13      124213
# 18.69      121006
# 16.7       118600
# 52.08      114888
# 16.12      114267
# 11.55      110508
# 9.52       109953
# 16.68      108283
# 3208.51    106156
# 3095.45    103122
# 14.45      102845
# 2818.73     93669
# 16.04       92778
# 35.31       78778
# 6.26        72449
# Name: count, dtype: Int64
# ------------------------------
# POPDENSGEO2
# 2725.889893    97237
# 226.729996     86784
# 92.940002      85747
# 259.790009     75071
# 27.02          68422
#                ...
# 4.7             2042
# 1.72            1919
# 2.71            1881
# 3.57            1739
# 2.15            1399
# Name: count, Length: 343, dtype: Int64
# ------------------------------
# GEO1_MZ
# Nampula             1171056
# Zambézia            1114995
# Tete                 522328
# Sofala               490706
# Cabo Delgado         488632
# Manica               402277
# Maputo               372870
# Inhambane            368760
# Gaza                 349750
# Niassa               345208
# Cidade de Maputo     302947
# Name: count, dtype: int64
# ------------------------------
# GEO2_MZ
# Cidade da Matola                                   202536
# Cidade de Nampula, Rapale                          191880
# Beira, Dondo                                       180655
# Xai-Xai, Bilene, Mandlakazi, Limpopo, Chongoene    179257
# Milange, Molumbo                                   165198
#                                                     ...
# Muembe                                               8555
# Majune                                               8515
# Massingir                                            8510
# Meluco                                               8080
# Muanza                                               7507
# Name: count, Length: 118, dtype: int64
# ------------------------------
# OWNERSHIP
# Owned                    4101543
# Not owned                 356732
# Unknown                    16695
# NIU (not in universe)       2128
# Name: count, dtype: int64
# ------------------------------
# OWNERSHIPD
# Owned                           4101543
# Renting, not specified           196241
# Free/usufruct (no cash rent)     123258
# Not owned, other                  37233
# Unknown                           16695
# NIU (not in universe)              2128
# Name: count, dtype: int64
# ------------------------------
# ELECTRIC
# No                       4855794
# Yes                      1022786
# Unknown                    44435
# NIU (not in universe)       6514
# Name: count, dtype: int64
# ------------------------------
# WATSUP
# No piped water                               4384590
# Have access to public piped water             558820
# Piped within the building or plot of land     322416
# Piped outside the dwelling                    280231
# Piped inside dwelling                         209057
# Piped, shared with other households           167901
# NIU (not in universe)                           6514
# Name: count, dtype: int64
# ------------------------------
# PHONE
# No                       4407363
# Yes                        67638
# NIU (not in universe)       2097
# Name: count, dtype: int64
# ------------------------------
# AUTOS
# No autos                         4309730
# Have auto, number unspecified     165279
# NIU (not in universe)               2089
# Name: count, dtype: int64
# ------------------------------
# MOTORCYCLE
# No motorcycles                         4218138
# Have motorcycle, number unspecified     256861
# NIU (not in universe)                     2099
# Name: count, dtype: int64
# ------------------------------
# BIKE
# No bicycles                           2932357
# Have a bicycle, number unspecified    1542825
# NIU (not in universe)                    1916
# Name: count, dtype: int64
# ------------------------------
# COMPUTER
# No                       4311687
# Yes                       163304
# NIU (not in universe)       2107
# Name: count, dtype: int64
# ------------------------------
# TV
# No                                             3637003
# Yes, color or black-and-white not specified     838092
# NIU (not in universe)                             2003
# Name: count, dtype: int64
# ------------------------------
# RADIO
# No                       3399245
# Yes                      2488559
# Unknown/missing            35566
# NIU (not in universe)       6159
# Name: count, dtype: int64
# ------------------------------
# ROOMS
# 2                        1823734
# 3                        1448280
# 1                        1267659
# 4                        1164035
# 5                         139114
# 6                          41806
# 7                          17656
# 8                           9770
# NIU (not in universe)       6514
# 9                           5414
# 10                          2722
# 11                          1001
# 12                           849
# 13                           350
# 14                           211
# 16                           154
# 15                            85
# 20                            79
# 19                            36
# 17                            30
# 18                            30
# Name: count, dtype: int64
# ------------------------------
# BEDROOMS
# 1                        2642518
# 2                        2117510
# 3                         882633
# 4                         229758
# 5                          31279
# 6                          10988
# NIU (not in universe)       6514
# 7                           3988
# 8                           1865
# 9                           1044
# 10                           761
# 11                           205
# 12                           162
# 13                           156
# 15                           109
# 14                            39
# Name: count, dtype: int64
# ------------------------------
# TOILET
# Non-flush, latrine                  3071681
# No toilet                           2442753
# Flush toilet                         279299
# Non-flush, other and unspecified     129234
# NIU (not in universe)                  6514
# Unknown                                  48
# Name: count, dtype: int64
# ------------------------------
# FLOOR
# None/unfinished (earth)    3127080
# Cement                     1189601
# Tile                         85128
# Wood                         35572
# Other finished, n.e.c.       32284
# Marble                        5293
# NIU (not in universe)         2128
# Unknown/missing                 12
# Name: count, dtype: int64
# ------------------------------
# WALL
# Mud with wood/wattle                   1867898
# Adobe                                  1617814
# Reed, bamboo, or palm                   930565
# Cement blocks                           893085
# Brick                                   455104
# Wood, fibercement, zinc, or plywood      99786
# Other material                           54855
# NIU (not in universe)                     6514
# Plastic sheeting, cardboard               3896
# Unknown/missing                             12
# Name: count, dtype: int64
# ------------------------------
# ROOF
# Thatch (straw, grass, leaves, palm, etc.)    3730276
# Zinc or tin                                  1886511
# Asbestos                                      141497
# Reinforced concrete (slab)                     94962
# Other, unspecified                             49598
# Tile, unspecified material                     12555
# Tile or cement                                  7604
# NIU (not in universe)                           6514
# Unknown/missing                                   12
# Name: count, dtype: int64
# ------------------------------
# HHTYPE
# Married/cohab couple with children               2419390
# Extended family, relatives only                  2167380
# Single-parent family                              661478
# Married/cohab couple, no children                 217894
# Composite household, family and non-relatives     181851
# One-person household                              137763
# Unclassifiable                                     65964
# Polygamous family                                  64425
# Non-family household                                9079
# Group quarters                                      4305
# Name: count, dtype: int64
# ------------------------------
# NFAMS
# 1 family              5737071
# 2 families             154501
# 3 families              23228
# 4 families               7002
# 5 families               2829
# 9 or more families       2328
# 6 families               1387
# 7 families                773
# 8 families                410
# Name: count, dtype: int64
# ------------------------------
# NCOUPLES
# 1 couple                           4179024
# No married couples in household    1565794
# 2 couples                           158045
# 3 couples                            22063
# 4 couples                             3885
# 5 couples                              493
# 6 couples                              177
# 7 couples                               48
# Name: count, dtype: int64
# ------------------------------
# NMOTHERS
# 1 mother                          4285402
# No mothers in household            901078
# 2 mothers                          581010
# 3 mothers                          123383
# 4 mothers                           28352
# 5 mothers                            7077
# 6 mothers                            2120
# 7 mothers                             684
# 8 mothers                             263
# 9 or more mothers in household        160
# Name: count, dtype: int64
# ------------------------------
# NFATHERS
# 1 father                   3883699
# No fathers in household    1889611
# 2 fathers                   136049
# 3 fathers                    17246
# 4 fathers                     2489
# 5 fathers                      310
# 6 fathers                      125
# Name: count, dtype: int64
# ------------------------------
# PERNUM
# 1     1421356
# 2     1244749
# 3      938952
# 4      817218
# 5      589290
# 6      391028
# 7      223735
# 8      130323
# 9       71516
# 10      37429
# 11      22380
# 12      13848
# 13       8510
# 14       5591
# 15       3804
# 16       2655
# 17       1828
# 18       1306
# 19        877
# 20        671
# 21        526
# 22        390
# 23        291
# 24        247
# 25        184
# 26        147
# 27        119
# 28         93
# 29         73
# 30         60
# 31         55
# 32         43
# 33         35
# 34         35
# 35         32
# 36         24
# 37         17
# 38         15
# 39         15
# 40         10
# 41         10
# 44          9
# 42          8
# 43          8
# 45          6
# 46          4
# 47          3
# 48          2
# 49          1
# 50          1
# Name: count, dtype: Int64
# ------------------------------
# PERWT
# 10.00    3433748
# 10.01      53925
# 9.96       50629
# 9.89       46009
# 10.08      43285
#           ...
# 12.27         10
# 14.13          8
# 16.13          7
# 31.29          7
# 53.50          2
# Name: count, Length: 431, dtype: int64
# ------------------------------
# RESIDENT
# Present resident    5754489
# Absent resident      175040
# Name: count, dtype: int64
# ------------------------------
# FAMSIZE
# 6                           969044
# 5                           957477
# 4                           890400
# 3 family members present    690360
# 7                           636081
# 8                           460625
# 2 family members present    402746
# 9                           304106
# 1 family member present     180905
# 10                          148710
# 11                           95776
# 12                           64187
# 13                           37477
# 14                           25687
# 15                           17782
# 16                           13169
# 17                            9206
# 18                            7175
# 19                            3967
# 20                            2901
# 21                            2664
# 22                            1964
# 24                            1314
# 23                            1140
# 25                            1074
# 27                             637
# 26                             622
# 28                             423
# 29                             373
# 31                             313
# 30                             170
# 32                             152
# 47                             139
# 36                             137
# 35                             127
# 34                              97
# 33                              91
# 44                              80
# 38                              75
# 45                              45
# 41                              40
# 37                              36
# 39                              35
# Name: count, dtype: int64
# ------------------------------
# NCHILD
# 0                                  4019086
# 1                                   553090
# 2                                   439260
# 3                                   351532
# 4                                   272974
# 5                                   152305
# 6                                    82871
# 7                                    36932
# 8                                    12763
# 9 or more children in household       8716
# Name: count, dtype: int64
# ------------------------------
# NCHLT5
# 0                                                  4680149
# 1                                                   772837
# 2                                                   413487
# 3                                                    55652
# 4                                                     6222
# 5                                                      879
# 6                                                      197
# 7                                                       67
# 8                                                       27
# 9 or more own children under age 5 in household         12
# Name: count, dtype: int64
# ------------------------------
# ELDCH
# No own child in household    4019086
# 6                              94998
# 4                              94998
# 10                             92658
# 7                              92299
# 12                             92077
# 3                              91983
# 5                              89211
# 1                              88614
# 2                              86847
# 15                             83486
# 8                              79720
# 14                             79186
# 9                              78877
# 0                              77511
# 13                             77285
# 11                             71084
# 17                             69378
# 16                             67564
# 18                             62302
# 20                             46930
# 19                             45592
# 22                             31581
# 21                             30251
# 23                             23617
# 25                             20339
# 24                             18846
# 27                             13837
# 26                             13585
# 28                             11273
# 30                             11073
# 29                              9071
# 32                              7491
# 50 or older                     6981
# 31                              6344
# 35                              5465
# 33                              4706
# 34                              4451
# 37                              3802
# 36                              3599
# 38                              3136
# 40                              3025
# 39                              2841
# 42                              2267
# 41                              1949
# 45                              1604
# 43                              1558
# 47                              1229
# 44                              1121
# 46                              1023
# 48                               951
# 49                               827
# Name: count, dtype: int64
# ------------------------------
# YNGCH
# No own child in household    4019086
# 1                             342572
# 0                             314138
# 2                             283533
# 3                             187424
# 4                             121713
# 5                              86838
# 6                              71660
# 7                              62587
# 8                              47099
# 10                             43424
# 9                              39424
# 12                             35235
# 11                             30652
# 13                             27247
# 14                             24399
# 15                             23835
# 17                             17817
# 16                             17392
# 18                             15859
# 20                             11872
# 19                             11071
# 22                              8551
# 21                              7849
# 23                              7041
# 25                              6760
# 50 or older                     5913
# 24                              5670
# 27                              4788
# 30                              4624
# 26                              4199
# 28                              4194
# 32                              3589
# 29                              3526
# 35                              2836
# 31                              2632
# 33                              2255
# 34                              2243
# 37                              2211
# 40                              1845
# 38                              1812
# 36                              1798
# 39                              1708
# 42                              1442
# 45                              1147
# 41                              1110
# 43                              1099
# 47                               962
# 44                               791
# 48                               735
# 46                               668
# 49                               654
# Name: count, dtype: int64
# ------------------------------
# RELATE
# Child             2734855
# Head              1418398
# Spouse/partner     900781
# Other relative     832832
# Non-relative        42462
# Unknown               201
# Name: count, dtype: int64
# ------------------------------
# RELATED
# Biological child                            2011496
# Head                                        1418398
# Spouse/partner                               900781
# Child                                        630642
# Other relative, not elsewhere classified     406009
# Grandchild                                   338574
# Stepchild                                     72109
# Child-in-law                                  57767
# Non-relative                                  42462
# Parent                                        30482
# Adopted child                                 20608
# Unknown                                         201
# Name: count, dtype: int64
# ------------------------------
# AGE
# 3          237397
# 4          236069
# 2 years    223665
# 6          215604
# 5          212441
#             ...
# 93            662
# 91            624
# 98            614
# 94            434
# 96            428
# Name: count, Length: 101, dtype: int64
# ------------------------------
# SEX
# Female    3085867
# Male      2843662
# Name: count, dtype: int64
# ------------------------------
# MARST
# Single/never married                3454507
# Married/in union                    2140231
# Widowed                              171267
# Separated/divorced/spouse absent     142098
# Unknown/missing                       21426
# Name: count, dtype: int64
# ------------------------------
# MARSTD
# Single/never married     3454507
# Consensual union         1596873
# Married, formally         543358
# Widowed                   171267
# Separated or divorced     142098
# Unknown/missing            21426
# Name: count, dtype: int64
# ------------------------------
# CONSENS
# NIU (not in universe)       3767872
# Yes, in consensual union    1596873
# No, married                  543358
# Unknown                       21426
# Name: count, dtype: int64
# ------------------------------
# CHBORN
# NIU (not in universe)    4062495
# No children               549397
# 1 child                   229985
# Unknown                   222156
# 2 children                201901
# 3                         165580
# 4                         140526
# 5                         107069
# 6                          81859
# 7                          58504
# 8                          42332
# 9                          27519
# 10                         20413
# 11                          9309
# 12                          7301
# 13                          2524
# 14                           305
# 15                           177
# 18                            73
# 16                            72
# 17                            32
# Name: count, dtype: int64
# ------------------------------
# CHSURV
# NIU (not in universe)    4644052
# 1 child                   244629
# Unknown                   228510
# 2 children                218046
# 3                         178186
# 4                         146853
# 5                         104808
# 6                          71741
# 7                          42739
# 8                          23029
# No children                10552
# 9                          10257
# 10                          5125
# 11                           549
# 12                           250
# 14                           147
# 13                            56
# Name: count, dtype: int64
# ------------------------------
# CHBORNF
# NIU (not in universe)    4062490
# No children               723974
# 1 child                   345997
# Unknown                   246389
# 2 children                235150
# 3                         146422
# 4                          84762
# 5                          44285
# 6                          22145
# 7                          10256
# 8                           4426
# 9                           1955
# 10                           716
# 11                           309
# 12                           158
# 13                            95
# Name: count, dtype: int64
# ------------------------------
# CHBORNM
# NIU (not in universe)    4062491
# No children               722092
# 1 child                   345864
# Unknown                   246934
# 2 children                237047
# 3                         148408
# 4                          85437
# 5                          44320
# 6                          20796
# 7                           9367
# 8                           4024
# 9                           1648
# 10                           631
# 11                           276
# 12                           110
# 13                            84
# Name: count, dtype: int64
# ------------------------------
# CHSURVF
# NIU (not in universe)    4279332
# No children               557630
# 1 child                   365795
# Unknown                   251035
# 2 children                236295
# 3                         134095
# 4                          64865
# 5                          26244
# 6                           9340
# 7                           3274
# 8                            949
# 9                            390
# 10                           126
# 11                            99
# 12                            60
# Name: count, dtype: int64
# ------------------------------
# CHSURVM
# NIU (not in universe)    4279328
# No children               563830
# 1 child                   363935
# Unknown                   251622
# 2 children                236990
# 3                         132512
# 4                          63313
# 5                          25482
# 6                           8335
# 7                           2851
# 8                            758
# 9                            309
# 12                           103
# 10                            99
# 11                            62
# Name: count, dtype: int64
# ------------------------------
# BIRTHSLYR
# NIU (not in universe)    4580807
# None                      838575
# Unknown                   279940
# 1 (1 or more)             204453
# 2                          10913
# 4+                         10250
# 3                           4591
# Name: count, dtype: int64
# ------------------------------
# BIRTHSURV
# NIU (not in universe)    4884231
# 0                         551294
# Unknown                   282160
# 1 (1 or more)             189062
# 2                           9392
# 4+                          9282
# 3                           4108
# Name: count, dtype: int64
# ------------------------------
# MORTMOT
# Alive                    4357582
# Dead                     1288518
# NIU (not in universe)     217741
# Missing                    60419
# Does not know               5269
# Name: count, dtype: int64
# ------------------------------
# MORTFAT
# Alive            2993322
# Dead             1422305
# Missing            54867
# Does not know       6604
# Name: count, dtype: int64
# ------------------------------
# NATIVITY
# Native-born        5826650
# Foreign-born         86331
# Unknown/missing      16548
# Name: count, dtype: int64
# ------------------------------
# CITIZEN
# Citizen, not specified    5810019
# Unknown                     83920
# Not a citizen               35590
# Name: count, dtype: int64
# ------------------------------
# NATION
# Mozambique                      5810019
# Unknown                           83920
# Malawi                            13960
# South Africa                       5167
# Zimbabwe                           4501
# Other countries n.s.               2917
# Tanzania                           2037
# Portugal                           1609
# Cape Verde                          951
# Zambia                              864
# India                               596
# Lesotho                             372
# Congo (Republic of)                 237
# Africa, other or n.s.               224
# Europe, other or n.s.               193
# Pakistan                            193
# Democratic Republic of Congo        178
# Angola                              174
# Sao Tome and Principe               157
# Brazil                              130
# United Kingdom                       92
# Burundi                              90
# Italy                                88
# China                                87
# Nigeria                              81
# Swaziland                            77
# Guinea                               72
# Namibia                              63
# United States                        59
# Rwanda                               48
# Americas, other or n.s.              48
# Chile                                46
# Sierra Leone                         37
# Kenya                                36
# Cuba                                 32
# Spain                                29
# France                               29
# Guinea-Bissau                        28
# Senegal                              26
# Equatorial Guinea                    26
# Togo                                 25
# South America, other or n.s.          8
# Asia, other or n.s.                   3
# Name: count, dtype: int64
# ------------------------------
# BPL1_MZ
# Nampula             1125631
# Zambézia            1104982
# Tete                 485264
# Cabo Delgado         468780
# Sofala               467411
# Inhambane            421202
# Gaza                 393989
# Manica               354186
# Niassa               319110
# Maputo               244502
# Cidade de Maputo     236655
# Unknown              215914
# Foreign Country       91903
# Name: count, dtype: int64
# ------------------------------
# BPL2_MZ
# Unknown                                                        215914
# Xai-Xai, Bilene, Mandlakazi, Limpopo, Chongoene                194598
# Cidade de Maputo, district unknown                             169933
# Milange, Molumbo                                               145777
# Quelimane, Inhassunge, Nicoadala                               134570
#                                                                 ...
# Massingir                                                        7493
# Namaacha                                                         6435
# Urbano 1 (KaMpfumo), Urbano 6 (KaTembe), Urbano 7 (KaNyaka)      6210
# Muanza                                                           6053
# Maputo province, district unknown                                4559
# Name: count, Length: 131, dtype: int64
# ------------------------------
# RELIGION
# Christian      2331478
# Muslim          816199
# No religion     700596
# Unknown         326740
# Other           302085
# Name: count, dtype: int64
# ------------------------------
# RELIGIOND
# Catholic (Roman or unspecified)    1223881
# Muslim                              816199
# No religion                         700596
# Zion Christian                      498039
# Unknown                             326740
# Other                               172799
# Other, not elsewhere classified     129286
# Anglican                             67616
# Name: count, dtype: int64
# ------------------------------
# RACE
# Black         5776291
# Unknown        115009
# Mixed race      27192
# White            4928
# Indian           4069
# Other            1145
# Pakistani         740
# Chinese           155
# Name: count, dtype: int64
# ------------------------------
# SPEAKPORT
# No                       2680888
# Yes                      2336226
# NIU (not in universe)     849008
# Unknown                    63407
# Name: count, dtype: int64
# ------------------------------
# LANGMZ
# Emakhuwa                     981988
# NIU (Not in universe)        693211
# Portuguese                   566293
# Xitsonga or Xichangana       362220
# Other languages              348614
# Elomwe                       267549
# Sena                         266094
# Cinyanja                     215801
# Cindau                       149326
# Xitswa                       139464
# Echuwabo                     138151
# Unknown                       73246
# Cicopi                        54100
# Cinyungwe                     45006
# Ciyao                         33274
# Shimakonde                    26555
# Chitewe                       26033
# Xirhonga                      22166
# Bitonga or Gitonga            18419
# Cishona                       16493
# Cibalke                       11563
# Kimwani                        8005
# Coti                           6079
# Kiswahili                      2648
# Other foreign language         2536
# Isizulo                         691
# Cinsenga                        476
# Other Mozambican language       260
# Isiswazi                        190
# Sena Care                        78
# Ekarungu                         76
# Citonga                          50
# Ciqwaka                          47
# Cingoni                          47
# Cindonje                         46
# Gombe                            42
# Tonga                            41
# Xilwandle                        38
# Cicewa                           35
# Ecocti                           34
# Merenje                          32
# Xikalanga                        30
# Phondzo                          26
# Xidzivi                          25
# Name: count, dtype: int64
# ------------------------------
# MTONGMZ
# Emakhuwa                     975414
# NIU (Not in universe)        693589
# Portuguese                   530914
# Other languages              375634
# Xitsonga or Xichangana       352515
# Sena                         274947
# Elomwe                       267865
# Cinyanja                     211731
# Cindau                       154478
# Echuwabo                     153986
# Xitswa                       150421
# Unknown                       74411
# Cinyungwe                     46203
# Ciyao                         34027
# Cichopi                       30773
# Shimakonde                    27564
# Chitewe                       25940
# Xirhonga                      23562
# Bitonga or Gitonga            22892
# Cishona                       17349
# Cibalke                       10695
# Kimwani                        7629
# Coti                           6024
# Other foreign language         3029
# Kiswahili                      2175
# Isizulo                        1279
# Cinsenga                        494
# Isiswazi                        392
# Other Mozambican language       306
# Cikhambani                      143
# Cilenje                          78
# Ekarungu                         66
# Citonga                          64
# Sutho                            59
# Cingoni                          53
# Cindonje                         51
# Sena Care                        44
# Xikalanga                        42
# Merenje                          40
# Gombe                            38
# Phondzo                          37
# Cilambwe                         35
# Ciqwaka                          31
# Tonga                            27
# Xilwandle                        27
# Cicewa                           25
# Name: count, dtype: int64
# ------------------------------
# SCHOOL
# No, never attended          2171806
# No, attended in the past    1572499
# Yes                         1323254
# NIU (not in universe)        699899
# Unknown/missing              162071
# Name: count, dtype: int64
# ------------------------------
# LIT
# No, illiterate           2729967
# Yes, literate            2308348
# NIU (not in universe)     845896
# Unknown/missing            45318
# Name: count, dtype: int64
# ------------------------------
# EDATTAIN
# Less than primary completed    4114908
# Primary completed               895301
# NIU (not in universe)           714633
# Secondary completed             122269
# Unknown                          58442
# University completed             23976
# Name: count, dtype: int64
# ------------------------------
# EDATTAIND
# No schooling                            2481563
# Some primary completed                  1633345
# NIU (not in universe)                    714633
# Primary (6 yrs) completed                698014
# Lower secondary general completed        189096
# Secondary, general track completed        97143
# Unknown/missing                           58442
# University completed                      23976
# Secondary, technical track completed      19038
# Lower secondary technical completed        8191
# Some college completed                     6088
# Name: count, dtype: int64
# ------------------------------
# EMPSTAT
# Employed                 2254116
# Inactive                 2253297
# NIU (not in universe)    1339375
# Unknown/missing            48315
# Unemployed                 34426
# Name: count, dtype: int64
# ------------------------------
# EMPSTATD
# At work                                        2023951
# NIU (not in universe)                          1339375
# In school                                       986552
# Housework                                       728664
# Inactive, other reasons                         439164
# At work, family holding, not specified          128935
# Have job, not at work in reference period        98510
# Health reasons, unable to work, or disabled      78812
# Unknown/missing                                  48315
# Unemployed, new worker                           21223
# Retirees and living on rent                      20105
# Unemployed, experienced worker                   13203
# Armed forces                                      2720
# Name: count, dtype: int64
# ------------------------------
# LABFORCE
# NIU (not in universe)         2632357
# Yes, in the labor force       2051983
# No, not in the labor force    1219862
# Unknown                         25327
# Name: count, dtype: int64
# ------------------------------
# EMPSECT
# NIU (not in universe)                                  3574114
# Individual/family enterprise, and self-employed        2038909
# Private, not elsewhere classified                       127617
# Unknown                                                  83361
# Public                                                   79799
# Mixed: public-private or parastatal                      17033
# Foreign government or non-governmental organization       5475
# Collective or cooperative                                 3221
# Name: count, dtype: int64
# ------------------------------
# OCCISCO
# NIU (not in universe)                         3574114
# Skilled agricultural and fishery workers      1736819
# Service workers and shop and market sales      187443
# Crafts and related trades workers              123417
# Unknown                                         96906
# Elementary occupations                          83287
# Technicians and associate professionals         38228
# Plant and machine operators and assemblers      36933
# Professionals                                   26593
# Clerks                                          15926
# Legislators, senior officials and managers       8815
# Armed forces                                     1048
# Name: count, dtype: int64
# ------------------------------
# INDGEN
# NIU (not in universe)                           3574114
# Agriculture, fishing, and forestry              1700200
# Wholesale and retail trade                       208044
# Unknown                                          146401
# Manufacturing                                     63793
# Public administration and defense                 46409
# Construction                                      46096
# Transportation, storage, and communications       27179
# Education                                         24834
# Private household services                        22039
# Other services                                    16281
# Business services and real estate                 14837
# Mining and extraction                             14354
# Health and social work                            11543
# Hotels and restaurants                             7489
# Electricity, gas, water and waste management       2824
# Financial services and insurance                   2216
# Other industry, n.e.c.                              876
# Name: count, dtype: int64
# ------------------------------
# DISABLED
# No, not disabled    5777200
# Yes, disabled        145637
# Unknown                6692
# Name: count, dtype: int64
# ------------------------------
# DISEMP
# Not disabled             3742063
# NIU (not in universe)    2060339
# Disabled                   78812
# Unknown                    48315
# Name: count, dtype: int64
# ------------------------------
# DISBLND
# No     4459047
# Yes      18051
# Name: count, dtype: int64
# ------------------------------
# DISDEAF
# No     4461514
# Yes      15584
# Name: count, dtype: int64
# ------------------------------
# DISMUTE
# No                       4102552
# NIU (not in universe)     311539
# Unknown                    55457
# Yes                         7550
# Name: count, dtype: int64
# ------------------------------
# DISLOWR
# No     4448015
# Yes      29083
# Name: count, dtype: int64
# ------------------------------
# DISUPPR
# No     4467553
# Yes       9545
# Name: count, dtype: int64
# ------------------------------
# DISMNTL
# No         5907088
# Yes          15749
# Unknown       6692
# Name: count, dtype: int64
# ------------------------------
# DISORIG
# No disability              4360202
# Disease                      52809
# Congenital, since birth      35561
# Other cause, n.e.c.           9865
# Work accident                 6320
# Other                         6221
# Transport accident            4279
# War injury                    1021
# Multiple causes                820
# Name: count, dtype: int64
# ------------------------------
# mig_provincial
# 0    5879434
# 1      50095
# Name: count, dtype: int64
# ------------------------------

# %%
for col in mig5_data.columns:
    print(mig5_data[col].value_counts())
    print('-'*30)
# Out:
# COUNTRY
# Mozambique    4974569
# Name: count, dtype: int64
# ------------------------------
# YEAR
# 2017    2122246
# 2007    1617537
# 1997    1234786
# Name: count, dtype: int64
# ------------------------------
# SAMPLE
# Mozambique 2017    2122246
# Mozambique 2007    1617537
# Mozambique 1997    1234786
# Name: count, dtype: int64
# ------------------------------
# SERIAL
# 26886000     59
# 261007000    49
# 442445000    49
# 361255000    48
# 115823000    47
#              ..
# 590466000     1
# 590464000     1
# 590461000     1
# 590484000     1
# 590477000     1
# Name: count, Length: 609525, dtype: Int64
# ------------------------------
# PERSONS
# 6     805890
# 5     777675
# 4     714101
# 3     577308
# 7     534657
# 8     394412
# 2     377002
# 9     266751
# 1     139068
# 10    130368
# 11     84665
# 12     57273
# 13     33300
# 14     22402
# 15     15811
# 16     11717
# 17      8266
# 18      6541
# 19      3466
# 20      2606
# 21      2334
# 22      1909
# 24      1235
# 23       929
# 25       871
# 26       658
# 27       593
# 28       468
# 30       290
# 29       270
# 31       265
# 35       261
# 39       180
# 32       180
# 36       172
# 34       137
# 44       108
# 33        87
# 47        75
# 37        67
# 50        49
# 45        47
# 48        41
# 41        33
# 38        31
# Name: count, dtype: Int64
# ------------------------------
# HHWT
# 10.00    4943984
# 10.01      13961
# 9.99       12323
# 0.00        2267
# 10.02       2034
# Name: count, dtype: int64
# ------------------------------
# GQ
# Households                                            4967152
# 1-person unit created by splitting large household       2267
# Other group quarters                                     2187
# Institutions                                             1779
# Unknown/group quarters not identified                    1184
# Name: count, dtype: int64
# ------------------------------
# GQTYPE
# NIU (not in universe)                                                           2844906
# 1-person unit created by splitting large household                                 2267
# Other group quarters                                                               1302
# Unknown                                                                            1184
# Floating population                                                                 749
# Boarding school or student housing                                                  706
# Military or police institution                                                      532
# Hospital, nursing home, hospice, or instutions for persons with disabilities        265
# Religious institution, monastery, seminary, or convent                              152
# Hotel, pension, lodging, or boarding house                                          136
# Prisons, reformatories, or correctional institutions                                124
# Name: count, dtype: int64
# ------------------------------
# UNREL
# 0     4799657
# 1      137866
# 2       21587
# 3        6819
# 4        3051
# 9+       2164
# 5        1470
# 6         907
# 7         590
# 8         458
# Name: count, dtype: int64
# ------------------------------
# URBAN
# Rural      3396668
# Urban      1577743
# Unknown        158
# Name: count, dtype: int64
# ------------------------------
# POPDENSGEO1
# 70.21      422009
# 48.64      384971
# 51.82      315673
# 37.83      299462
# 28.44      230659
# 38.61      229119
# 25.38      201865
# 29.02      179329
# 32.01      176531
# 81.62      150111
# 30.12      146460
# 17.81      139889
# 24.33      133219
# 14.03      132428
# 20.92      129895
# 21.13      121799
# 18.44      115050
# 23.34      112112
# 19.13      105596
# 18.69      104192
# 16.7       101995
# 52.08      100708
# 16.12       98725
# 3208.51     95226
# 16.68       94212
# 11.55       92618
# 3095.45     91693
# 14.45       89662
# 9.52        88436
# 2818.73     82993
# 16.04       78544
# 35.31       69182
# 6.26        60206
# Name: count, dtype: Int64
# ------------------------------
# POPDENSGEO2
# 2725.889893    83017
# 226.729996     72583
# 92.940002      69255
# 259.790009     64920
# 27.02          57826
#                ...
# 4.7             1691
# 1.72            1611
# 2.71            1561
# 3.57            1389
# 2.15            1138
# Name: count, Length: 343, dtype: Int64
# ------------------------------
# GEO1_MZ
# Nampula             966801
# Zambézia            915092
# Tete                434372
# Sofala              415346
# Cabo Delgado        411219
# Manica              337116
# Inhambane           320203
# Maputo              320001
# Gaza                303437
# Niassa              281070
# Cidade de Maputo    269912
# Name: count, dtype: int64
# ------------------------------
# GEO2_MZ
# Cidade da Matola                                   175526
# Cidade de Nampula, Rapale                          162295
# Beira, Dondo                                       157716
# Xai-Xai, Bilene, Mandlakazi, Limpopo, Chongoene    156381
# Milange, Molumbo                                   133618
#                                                     ...
# Massingir                                            7255
# Majune                                               6920
# Muembe                                               6882
# Meluco                                               6874
# Muanza                                               6091
# Name: count, Length: 118, dtype: int64
# ------------------------------
# OWNERSHIP
# Owned                    3421165
# Not owned                 302827
# Unknown                    13838
# NIU (not in universe)       1953
# Name: count, dtype: int64
# ------------------------------
# OWNERSHIPD
# Owned                           3421165
# Renting, not specified           168227
# Free/usufruct (no cash rent)     103704
# Not owned, other                  30896
# Unknown                           13838
# NIU (not in universe)              1953
# Name: count, dtype: int64
# ------------------------------
# ELECTRIC
# No                       4041795
# Yes                       889189
# Unknown                    37442
# NIU (not in universe)       6143
# Name: count, dtype: int64
# ------------------------------
# WATSUP
# No piped water                               3640110
# Have access to public piped water             476446
# Piped within the building or plot of land     277882
# Piped outside the dwelling                    246846
# Piped inside dwelling                         184469
# Piped, shared with other households           142673
# NIU (not in universe)                           6143
# Name: count, dtype: int64
# ------------------------------
# PHONE
# No                       3679566
# Yes                        58295
# NIU (not in universe)       1922
# Name: count, dtype: int64
# ------------------------------
# AUTOS
# No autos                         3593375
# Have auto, number unspecified     144493
# NIU (not in universe)               1915
# Name: count, dtype: int64
# ------------------------------
# MOTORCYCLE
# No motorcycles                         3522797
# Have motorcycle, number unspecified     215058
# NIU (not in universe)                     1928
# Name: count, dtype: int64
# ------------------------------
# BIKE
# No bicycles                           2463784
# Have a bicycle, number unspecified    1274238
# NIU (not in universe)                    1761
# Name: count, dtype: int64
# ------------------------------
# COMPUTER
# No                       3595161
# Yes                       142688
# NIU (not in universe)       1934
# Name: count, dtype: int64
# ------------------------------
# TV
# No                                             3011095
# Yes, color or black-and-white not specified     726853
# NIU (not in universe)                             1835
# Name: count, dtype: int64
# ------------------------------
# RADIO
# No                       2836450
# Yes                      2102255
# Unknown/missing            30053
# NIU (not in universe)       5811
# Name: count, dtype: int64
# ------------------------------
# ROOMS
# 2                        1515366
# 3                        1220870
# 1                        1048157
# 4                         991736
# 5                         121725
# 6                          36862
# 7                          15567
# 8                           8611
# NIU (not in universe)       6143
# 9                           4741
# 10                          2354
# 11                           864
# 12                           739
# 13                           298
# 14                           185
# 16                           129
# 15                            73
# 20                            62
# 19                            32
# 18                            28
# 17                            27
# Name: count, dtype: int64
# ------------------------------
# BEDROOMS
# 1                        2185100
# 2                        1778469
# 3                         762002
# 4                         198699
# 5                          27334
# 6                           9596
# NIU (not in universe)       6143
# 7                           3486
# 8                           1632
# 9                            904
# 10                           641
# 11                           170
# 12                           136
# 13                           135
# 15                            89
# 14                            33
# Name: count, dtype: int64
# ------------------------------
# TOILET
# Non-flush, latrine                  2592756
# No toilet                           2017372
# Flush toilet                         246514
# Non-flush, other and unspecified     111748
# NIU (not in universe)                  6143
# Unknown                                  36
# Name: count, dtype: int64
# ------------------------------
# FLOOR
# None/unfinished (earth)    2574150
# Cement                     1026515
# Tile                         74002
# Wood                         31925
# Other finished, n.e.c.       26724
# Marble                        4504
# NIU (not in universe)         1953
# Unknown/missing                 10
# Name: count, dtype: int64
# ------------------------------
# WALL
# Mud with wood/wattle                   1553736
# Adobe                                  1331018
# Reed, bamboo, or palm                   786251
# Cement blocks                           778457
# Brick                                   383205
# Wood, fibercement, zinc, or plywood      86253
# Other material                           46104
# NIU (not in universe)                     6143
# Plastic sheeting, cardboard               3392
# Unknown/missing                             10
# Name: count, dtype: int64
# ------------------------------
# ROOF
# Thatch (straw, grass, leaves, palm, etc.)    3086620
# Zinc or tin                                  1613439
# Asbestos                                      123939
# Reinforced concrete (slab)                     84878
# Other, unspecified                             41758
# Tile, unspecified material                     11216
# Tile or cement                                  6566
# NIU (not in universe)                           6143
# Unknown/missing                                   10
# Name: count, dtype: int64
# ------------------------------
# HHTYPE
# Married/cohab couple with children               1940990
# Extended family, relatives only                  1871917
# Single-parent family                              531339
# Married/cohab couple, no children                 216327
# Composite household, family and non-relatives     156552
# One-person household                              136497
# Unclassifiable                                     55969
# Polygamous family                                  52350
# Non-family household                                8662
# Group quarters                                      3966
# Name: count, dtype: int64
# ------------------------------
# NFAMS
# 1 family              4807858
# 2 families             132914
# 3 families              20393
# 4 families               6256
# 5 families               2508
# 9 or more families       2272
# 6 families               1252
# 7 families                727
# 8 families                389
# Name: count, dtype: int64
# ------------------------------
# NCOUPLES
# 1 couple                           3480535
# No married couples in household    1332776
# 2 couples                           138336
# 3 couples                            18961
# 4 couples                             3345
# 5 couples                              424
# 6 couples                              150
# 7 couples                               42
# Name: count, dtype: int64
# ------------------------------
# NMOTHERS
# 1 mother                          3501726
# No mothers in household            847652
# 2 mothers                          490631
# 3 mothers                          102709
# 4 mothers                           23427
# 5 mothers                            5797
# 6 mothers                            1722
# 7 mothers                             558
# 8 mothers                             215
# 9 or more mothers in household        132
# Name: count, dtype: int64
# ------------------------------
# NFATHERS
# 1 father                   3184845
# No fathers in household    1655879
# 2 fathers                   116947
# 3 fathers                    14434
# 4 fathers                     2100
# 5 fathers                      257
# 6 fathers                      107
# Name: count, dtype: int64
# ------------------------------
# PERNUM
# 1     1411973
# 2     1119212
# 4      583146
# 5      529611
# 3      501447
# 6      362206
# 7      205244
# 8      116428
# 9       61813
# 10      31258
# 11      18311
# 12      11227
# 13       6904
# 14       4595
# 15       3115
# 16       2180
# 17       1496
# 18       1050
# 19        725
# 20        548
# 21        430
# 22        324
# 23        251
# 24        215
# 25        154
# 26        128
# 27        105
# 28         85
# 29         64
# 30         53
# 31         44
# 32         35
# 34         31
# 33         29
# 35         26
# 36         20
# 37         14
# 39         13
# 38         12
# 40          8
# 43          7
# 41          6
# 42          6
# 44          6
# 45          4
# 46          3
# 47          3
# 48          2
# 49          1
# 50          1
# Name: count, dtype: Int64
# ------------------------------
# PERWT
# 10.00    2885671
# 9.89       39582
# 10.01      39271
# 9.96       38014
# 10.03      35625
#           ...
# 12.27         10
# 14.13          8
# 31.29          7
# 16.13          7
# 53.50          2
# Name: count, Length: 430, dtype: int64
# ------------------------------
# RESIDENT
# Present resident    4813326
# Absent resident      161243
# Name: count, dtype: int64
# ------------------------------
# FAMSIZE
# 6                           797051
# 5                           777802
# 4                           715336
# 3 family members present    579680
# 7                           530128
# 8                           387817
# 2 family members present    380761
# 9                           258012
# 1 family member present     176081
# 10                          126739
# 11                           81638
# 12                           54660
# 13                           31805
# 14                           21725
# 15                           15035
# 16                           11048
# 17                            7748
# 18                            6024
# 19                            3305
# 20                            2417
# 21                            2216
# 22                            1648
# 24                            1102
# 23                             950
# 25                             866
# 26                             532
# 27                             531
# 28                             355
# 29                             317
# 31                             262
# 30                             145
# 32                             122
# 47                             115
# 36                             108
# 35                              99
# 34                              84
# 33                              81
# 44                              64
# 38                              63
# 41                              33
# 39                              32
# 37                              30
# 45                               2
# Name: count, dtype: int64
# ------------------------------
# NCHILD
# 0                                  3076451
# 1                                   548649
# 2                                   435727
# 3                                   349439
# 4                                   271527
# 5                                   151849
# 6                                    82687
# 7                                    36814
# 8                                    12715
# 9 or more children in household       8711
# Name: count, dtype: int64
# ------------------------------
# NCHLT5
# 0                                                  3733472
# 1                                                   766742
# 2                                                   411546
# 3                                                    55436
# 4                                                     6195
# 5                                                      876
# 6                                                      196
# 7                                                       67
# 8                                                       27
# 9 or more own children under age 5 in household         12
# Name: count, dtype: int64
# ------------------------------
# ELDCH
# No own child in household    3076451
# 6                              94349
# 4                              94241
# 10                             92088
# 7                              91551
# 12                             91536
# 3                              91229
# 5                              88535
# 1                              87841
# 2                              86096
# 15                             83005
# 8                              79037
# 14                             78694
# 9                              78267
# 0                              76894
# 13                             76881
# 11                             70720
# 17                             69044
# 16                             67240
# 18                             61997
# 20                             46728
# 19                             45319
# 22                             31422
# 21                             30096
# 23                             23490
# 25                             20269
# 24                             18808
# 27                             13775
# 26                             13532
# 28                             11248
# 30                             11039
# 29                              9047
# 32                              7458
# 50 or older                     6960
# 31                              6330
# 35                              5430
# 33                              4682
# 34                              4427
# 37                              3782
# 36                              3580
# 38                              3126
# 40                              3004
# 39                              2833
# 42                              2258
# 41                              1943
# 45                              1598
# 43                              1546
# 47                              1231
# 44                              1116
# 46                              1022
# 48                               949
# 49                               825
# Name: count, dtype: int64
# ------------------------------
# YNGCH
# No own child in household    3076451
# 1                             340385
# 0                             312340
# 2                             281722
# 3                             185956
# 4                             120694
# 5                              86116
# 6                              71136
# 7                              62176
# 8                              46788
# 10                             43200
# 9                              39176
# 12                             35035
# 11                             30510
# 13                             27107
# 14                             24245
# 15                             23703
# 17                             17690
# 16                             17336
# 18                             15761
# 20                             11820
# 19                             10988
# 22                              8488
# 21                              7812
# 23                              7002
# 25                              6740
# 50 or older                     5897
# 24                              5638
# 27                              4773
# 30                              4604
# 26                              4200
# 28                              4182
# 32                              3569
# 29                              3515
# 35                              2816
# 31                              2621
# 33                              2245
# 34                              2233
# 37                              2198
# 40                              1832
# 38                              1808
# 36                              1782
# 39                              1706
# 42                              1443
# 45                              1141
# 41                              1101
# 43                              1088
# 47                               963
# 44                               783
# 48                               734
# 46                               668
# 49                               652
# Name: count, dtype: int64
# ------------------------------
# RELATE
# Child             1944423
# Head              1409094
# Spouse/partner     894538
# Other relative     687676
# Non-relative        38680
# Unknown               158
# Name: count, dtype: int64
# ------------------------------
# RELATED
# Biological child                            1420683
# Head                                        1409094
# Spouse/partner                               894538
# Child                                        447593
# Other relative, not elsewhere classified     365466
# Grandchild                                   236088
# Stepchild                                     59602
# Child-in-law                                  55774
# Non-relative                                  38680
# Parent                                        30348
# Adopted child                                 16545
# Unknown                                         158
# Name: count, dtype: int64
# ------------------------------
# AGE
# 6                   212852
# 5                   207195
# 7                   201935
# 10                  180738
# 8                   172844
#                      ...
# 96                     426
# 3                      341
# 2 years                270
# 1 year                 259
# Less than 1 year       138
# Name: count, Length: 101, dtype: int64
# ------------------------------
# SEX
# Female    2602538
# Male      2372031
# Name: count, dtype: int64
# ------------------------------
# MARST
# Single/never married                2515729
# Married/in union                    2125606
# Widowed                              170740
# Separated/divorced/spouse absent     141489
# Unknown/missing                       21005
# Name: count, dtype: int64
# ------------------------------
# MARSTD
# Single/never married     2515729
# Consensual union         1585606
# Married, formally         540000
# Widowed                   170740
# Separated or divorced     141489
# Unknown/missing            21005
# Name: count, dtype: int64
# ------------------------------
# CONSENS
# NIU (not in universe)       2827958
# Yes, in consensual union    1585606
# No, married                  540000
# Unknown                       21005
# Name: count, dtype: int64
# ------------------------------
# CHBORN
# NIU (not in universe)    3122425
# No children               545234
# 1 child                   227701
# Unknown                   218761
# 2 children                199973
# 3                         164401
# 4                         139676
# 5                         106672
# 6                          81570
# 7                          58350
# 8                          42209
# 9                          27451
# 10                         20374
# 11                          9299
# 12                          7295
# 13                          2515
# 14                           306
# 15                           183
# 16                            72
# 18                            70
# 17                            32
# Name: count, dtype: int64
# ------------------------------
# CHSURV
# NIU (not in universe)    3699916
# 1 child                   242341
# Unknown                   224989
# 2 children                216169
# 3                         177025
# 4                         146062
# 5                         104424
# 6                          71452
# 7                          42596
# 8                          22950
# No children                10295
# 9                          10236
# 10                          5119
# 11                           545
# 12                           249
# 14                           146
# 13                            55
# Name: count, dtype: int64
# ------------------------------
# CHBORNF
# NIU (not in universe)    3122420
# No children               718540
# 1 child                   343119
# Unknown                   242450
# 2 children                233687
# 3                         145773
# 4                          84442
# 5                          44193
# 6                          22086
# 7                          10240
# 8                           4403
# 9                           1950
# 10                           710
# 11                           305
# 12                           157
# 13                            94
# Name: count, dtype: int64
# ------------------------------
# CHBORNM
# NIU (not in universe)    3122421
# No children               716768
# 1 child                   342715
# Unknown                   243065
# 2 children                235586
# 3                         147755
# 4                          85191
# 5                          44219
# 6                          20743
# 7                           9342
# 8                           4021
# 9                           1643
# 10                           631
# 11                           275
# 12                           109
# 13                            85
# Name: count, dtype: int64
# ------------------------------
# CHSURVF
# NIU (not in universe)    3335539
# No children               555751
# 1 child                   362969
# Unknown                   246975
# 2 children                234901
# 3                         133518
# 4                          64613
# 5                          26135
# 6                           9292
# 7                           3258
# 8                            943
# 9                            392
# 10                           126
# 11                           100
# 12                            57
# Name: count, dtype: int64
# ------------------------------
# CHSURVM
# NIU (not in universe)    3335551
# No children               562072
# 1 child                   360847
# Unknown                   247642
# 2 children                235598
# 3                         131908
# 4                          63100
# 5                          25398
# 6                           8305
# 7                           2823
# 8                            758
# 9                            308
# 12                            99
# 10                            98
# 11                            62
# Name: count, dtype: int64
# ------------------------------
# BIRTHSLYR
# NIU (not in universe)    3632198
# None                      838265
# Unknown                   275294
# 1 (1 or more)             203290
# 2                          10814
# 4+                         10166
# 3                           4542
# Name: count, dtype: int64
# ------------------------------
# BIRTHSURV
# NIU (not in universe)    3936868
# 0                         549652
# Unknown                   277460
# 1 (1 or more)             188009
# 2                           9295
# 4+                          9216
# 3                           4069
# Name: count, dtype: int64
# ------------------------------
# MORTMOT
# Alive            3644336
# Dead             1272711
# Missing            52327
# Does not know       5195
# Name: count, dtype: int64
# ------------------------------
# MORTFAT
# Alive            2303276
# Dead             1384832
# Missing            45808
# Does not know       5867
# Name: count, dtype: int64
# ------------------------------
# NATIVITY
# Native-born        4882291
# Foreign-born         77245
# Unknown/missing      15033
# Name: count, dtype: int64
# ------------------------------
# CITIZEN
# Citizen, not specified    4871670
# Unknown                     70280
# Not a citizen               32619
# Name: count, dtype: int64
# ------------------------------
# NATION
# Mozambique                      4871670
# Unknown                           70280
# Malawi                            13063
# South Africa                       4349
# Zimbabwe                           4200
# Other countries n.s.               2613
# Tanzania                           1918
# Portugal                           1543
# Zambia                              814
# Cape Verde                          808
# India                               564
# Lesotho                             304
# Congo (Republic of)                 228
# Africa, other or n.s.               200
# Pakistan                            192
# Europe, other or n.s.               178
# Democratic Republic of Congo        176
# Angola                              152
# Sao Tome and Principe               138
# Brazil                              122
# United Kingdom                       87
# China                                85
# Burundi                              84
# Italy                                84
# Nigeria                              74
# Guinea                               71
# Swaziland                            67
# Namibia                              53
# United States                        52
# Rwanda                               48
# Americas, other or n.s.              46
# Chile                                42
# Kenya                                35
# Sierra Leone                         33
# Cuba                                 32
# Spain                                28
# France                               27
# Senegal                              27
# Equatorial Guinea                    25
# Guinea-Bissau                        24
# Togo                                 22
# South America, other or n.s.          8
# Asia, other or n.s.                   3
# Name: count, dtype: int64
# ------------------------------
# BPL1_MZ
# Nampula             931347
# Zambézia            914003
# Tete                403426
# Cabo Delgado        394877
# Sofala              394864
# Inhambane           374163
# Gaza                349079
# Manica              292797
# Niassa              258465
# Maputo              207664
# Cidade de Maputo    202367
# Unknown             168991
# Foreign Country      82526
# Name: count, dtype: int64
# ------------------------------
# BPL2_MZ
# Xai-Xai, Bilene, Mandlakazi, Limpopo, Chongoene                173059
# Unknown                                                        168991
# Cidade de Maputo, district unknown                             144335
# Milange, Molumbo                                               116571
# Quelimane, Inhassunge, Nicoadala                               114153
#                                                                 ...
# Muembe                                                           6167
# Urbano 1 (KaMpfumo), Urbano 6 (KaTembe), Urbano 7 (KaNyaka)      5493
# Namaacha                                                         5298
# Muanza                                                           4803
# Maputo province, district unknown                                4102
# Name: count, Length: 131, dtype: int64
# ------------------------------
# RELIGION
# Christian      1957953
# Muslim          680720
# No religion     579155
# Unknown         268191
# Other           253764
# Name: count, dtype: int64
# ------------------------------
# RELIGIOND
# Catholic (Roman or unspecified)    1027762
# Muslim                              680720
# No religion                         579155
# Zion Christian                      419660
# Unknown                             268191
# Other                               145336
# Other, not elsewhere classified     108428
# Anglican                             56745
# Name: count, dtype: int64
# ------------------------------
# RACE
# Black         4846058
# Unknown         94756
# Mixed race      23756
# White            4487
# Indian           3696
# Other            1018
# Pakistani         660
# Chinese           138
# Name: count, dtype: int64
# ------------------------------
# SPEAKPORT
# No                       2621118
# Yes                      2300149
# Unknown                    52949
# NIU (not in universe)        353
# Name: count, dtype: int64
# ------------------------------
# LANGMZ
# Emakhuwa                     974711
# Portuguese                   552014
# Xitsonga or Xichangana       357904
# Other languages              345041
# Elomwe                       265897
# Sena                         264344
# Cinyanja                     214802
# Cindau                       148669
# Xitswa                       138538
# Echuwabo                     137445
# Unknown                       64494
# Cicopi                        53453
# Cinyungwe                     45013
# Ciyao                         33270
# Shimakonde                    26552
# Chitewe                       26025
# Xirhonga                      22154
# Bitonga or Gitonga            18423
# Cishona                       16492
# Cibalke                       11568
# Kimwani                        8001
# Coti                           6085
# Kiswahili                      2646
# Other foreign language         2538
# NIU (Not in universe)          1442
# Isizulo                         690
# Cinsenga                        476
# Other Mozambican language       261
# Isiswazi                        190
# Sena Care                        78
# Ekarungu                         77
# Citonga                          50
# Ciqwaka                          47
# Cingoni                          47
# Cindonje                         46
# Gombe                            41
# Tonga                            41
# Xilwandle                        38
# Cicewa                           35
# Ecocti                           34
# Merenje                          31
# Xikalanga                        30
# Phondzo                          25
# Xidzivi                          25
# Name: count, dtype: int64
# ------------------------------
# MTONGMZ
# Emakhuwa                     968009
# Portuguese                   518383
# Other languages              371340
# Xitsonga or Xichangana       347977
# Sena                         273145
# Elomwe                       266141
# Cinyanja                     210703
# Cindau                       153724
# Echuwabo                     152932
# Xitswa                       149254
# Unknown                       65570
# Cinyungwe                     46209
# Ciyao                         34021
# Cichopi                       30762
# Shimakonde                    27562
# Chitewe                       25938
# Xirhonga                      23551
# Bitonga or Gitonga            22893
# Cishona                       17345
# Cibalke                       10699
# Kimwani                        7628
# Coti                           6028
# Other foreign language         3027
# Kiswahili                      2169
# NIU (Not in universe)          1446
# Isizulo                        1281
# Cinsenga                        495
# Isiswazi                        393
# Other Mozambican language       303
# Cikhambani                      143
# Cilenje                          76
# Ekarungu                         67
# Citonga                          64
# Sutho                            59
# Cingoni                          53
# Cindonje                         51
# Sena Care                        44
# Xikalanga                        42
# Merenje                          39
# Gombe                            37
# Phondzo                          37
# Cilambwe                         34
# Ciqwaka                          31
# Tonga                            27
# Xilwandle                        26
# Cicewa                           25
# Name: count, dtype: int64
# ------------------------------
# SCHOOL
# No, never attended          2021434
# No, attended in the past    1556987
# Yes                         1302991
# Unknown/missing               92865
# NIU (not in universe)           292
# Name: count, dtype: int64
# ------------------------------
# LIT
# No, illiterate           2660373
# Yes, literate            2278409
# Unknown/missing            35449
# NIU (not in universe)        338
# Name: count, dtype: int64
# ------------------------------
# EDATTAIN
# Less than primary completed    3962365
# Primary completed               813236
# Secondary completed             118858
# Unknown                          56605
# University completed             22838
# NIU (not in universe)              667
# Name: count, dtype: int64
# ------------------------------
# EDATTAIND
# No schooling                            2334915
# Some primary completed                  1627450
# Primary (6 yrs) completed                619652
# Lower secondary general completed        185584
# Secondary, general track completed        94244
# Unknown/missing                           56605
# University completed                      22838
# Secondary, technical track completed      18533
# Lower secondary technical completed        8000
# Some college completed                     6081
# NIU (not in universe)                       667
# Name: count, dtype: int64
# ------------------------------
# EMPSTAT
# Employed                 2242927
# Inactive                 2229226
# NIU (not in universe)     421493
# Unknown/missing            47039
# Unemployed                 33884
# Name: count, dtype: int64
# ------------------------------
# EMPSTATD
# At work                                        2013998
# In school                                       977708
# Housework                                       723119
# Inactive, other reasons                         429958
# NIU (not in universe)                           421493
# At work, family holding, not specified          128969
# Have job, not at work in reference period        97229
# Health reasons, unable to work, or disabled      78456
# Unknown/missing                                  47039
# Unemployed, new worker                           21003
# Retirees and living on rent                      19985
# Unemployed, experienced worker                   12881
# Armed forces                                      2731
# Name: count, dtype: int64
# ------------------------------
# LABFORCE
# Yes, in the labor force       2041229
# NIU (not in universe)         1701480
# No, not in the labor force    1207128
# Unknown                         24732
# Name: count, dtype: int64
# ------------------------------
# EMPSECT
# NIU (not in universe)                                  2631886
# Individual/family enterprise, and self-employed        2030976
# Private, not elsewhere classified                       126026
# Unknown                                                  81674
# Public                                                   78564
# Mixed: public-private or parastatal                      16818
# Foreign government or non-governmental organization       5418
# Collective or cooperative                                 3207
# Name: count, dtype: int64
# ------------------------------
# OCCISCO
# NIU (not in universe)                         2631886
# Skilled agricultural and fishery workers      1731764
# Service workers and shop and market sales      185260
# Crafts and related trades workers              122327
# Unknown                                         94996
# Elementary occupations                          82845
# Technicians and associate professionals         37735
# Plant and machine operators and assemblers      36503
# Professionals                                   25851
# Clerks                                          15716
# Legislators, senior officials and managers       8694
# Armed forces                                      992
# Name: count, dtype: int64
# ------------------------------
# INDGEN
# NIU (not in universe)                           2631886
# Agriculture, fishing, and forestry              1695731
# Wholesale and retail trade                       206217
# Unknown                                          143570
# Manufacturing                                     63355
# Construction                                      45686
# Public administration and defense                 45273
# Transportation, storage, and communications       26843
# Education                                         24549
# Private household services                        21779
# Other services                                    16124
# Business services and real estate                 14601
# Mining and extraction                             14270
# Health and social work                            11527
# Hotels and restaurants                             7336
# Electricity, gas, water and waste management       2806
# Financial services and insurance                   2172
# Other industry, n.e.c.                              844
# Name: count, dtype: int64
# ------------------------------
# DISABLED
# No, not disabled    4830873
# Yes, disabled        137609
# Unknown                6087
# Name: count, dtype: int64
# ------------------------------
# DISEMP
# Not disabled             3716691
# NIU (not in universe)    1132383
# Disabled                   78456
# Unknown                    47039
# Name: count, dtype: int64
# ------------------------------
# DISBLND
# No     3722482
# Yes      17301
# Name: count, dtype: int64
# ------------------------------
# DISDEAF
# No     3725222
# Yes      14561
# Name: count, dtype: int64
# ------------------------------
# DISMUTE
# No         3679515
# Unknown      53119
# Yes           7149
# Name: count, dtype: int64
# ------------------------------
# DISLOWR
# No     3712368
# Yes      27415
# Name: count, dtype: int64
# ------------------------------
# DISUPPR
# No     3730628
# Yes       9155
# Name: count, dtype: int64
# ------------------------------
# DISMNTL
# No         4953677
# Yes          14805
# Unknown       6087
# Name: count, dtype: int64
# ------------------------------
# DISORIG
# No disability              3629663
# Disease                      50602
# Congenital, since birth      31805
# Other cause, n.e.c.           9543
# Work accident                 6246
# Other                         5947
# Transport accident            4187
# War injury                    1017
# Multiple causes                773
# Name: count, dtype: int64
# ------------------------------
# mig_provincial
# 0    4847198
# 1     127371
# Name: count, dtype: int64
# ------------------------------

# %% [markdown]
# ### Crosstabs

# %%
len(mig5_data.columns)
mig5_data.columns.tolist()
# Out:
# ['COUNTRY',
#  'YEAR',
#  'SAMPLE',
#  'SERIAL',
#  'PERSONS',
#  'HHWT',
#  'GQ',
#  'GQTYPE',
#  'UNREL',
#  'URBAN',
#  'POPDENSGEO1',
#  'POPDENSGEO2',
#  'GEO1_MZ',
#  'GEO2_MZ',
#  'OWNERSHIP',
#  'OWNERSHIPD',
#  'ELECTRIC',
#  'WATSUP',
#  'PHONE',
#  'AUTOS',
#  'MOTORCYCLE',
#  'BIKE',
#  'COMPUTER',
#  'TV',
#  'RADIO',
#  'ROOMS',
#  'BEDROOMS',
#  'TOILET',
#  'FLOOR',
#  'WALL',
#  'ROOF',
#  'HHTYPE',
#  'NFAMS',
#  'NCOUPLES',
#  'NMOTHERS',
#  'NFATHERS',
#  'PERNUM',
#  'PERWT',
#  'RESIDENT',
#  'FAMSIZE',
#  'NCHILD',
#  'NCHLT5',
#  'ELDCH',
#  'YNGCH',
#  'RELATE',
#  'RELATED',
#  'AGE',
#  'SEX',
#  'MARST',
#  'MARSTD',
#  'CONSENS',
#  'CHBORN',
#  'CHSURV',
#  'CHBORNF',
#  'CHBORNM',
#  'CHSURVF',
#  'CHSURVM',
#  'BIRTHSLYR',
#  'BIRTHSURV',
#  'MORTMOT',
#  'MORTFAT',
#  'NATIVITY',
#  'CITIZEN',
#  'NATION',
#  'BPL1_MZ',
#  'BPL2_MZ',
#  'RELIGION',
#  'RELIGIOND',
#  'RACE',
#  'SPEAKPORT',
#  'LANGMZ',
#  'MTONGMZ',
#  'SCHOOL',
#  'LIT',
#  'EDATTAIN',
#  'EDATTAIND',
#  'EMPSTAT',
#  'EMPSTATD',
#  'LABFORCE',
#  'EMPSECT',
#  'OCCISCO',
#  'INDGEN',
#  'DISABLED',
#  'DISEMP',
#  'DISBLND',
#  'DISDEAF',
#  'DISMUTE',
#  'DISLOWR',
#  'DISUPPR',
#  'DISMNTL',
#  'DISORIG',
#  'mig_provincial']

# %%
pd.crosstab(mig5_data['YEAR'], mig5_data['mig_provincial'], normalize='index')
# max_diff = abs(tab[0] - tab[1]).max()
# print(max_diff)
# Out:
# mig_provincial         0         1
# YEAR
# 1997            0.956966  0.043034
# 2007            0.974729  0.025271
# 2017            0.984283  0.015717

# %%
useful_features = []
useless_features = []

for col in mig5_data.columns:
    if col == 'mig_provincial':
        continue
    if mig5_data[col].nunique() > 20:
        continue

    tab = pd.crosstab(mig5_data[col], mig5_data['mig_provincial'], normalize='index')
    max_diff = tab[1].max() - tab[1].min()
    mean_rate = tab[1].mean()
    if max_diff >= 0.02:
        useful_features.append({'feature': col, 'max_diff': round(max_diff, 4), 'mean_rate': round(mean_rate, 4)})
    else:
        useless_features.append({'feature': col, 'max_diff': round(max_diff, 4), 'mean_rate': round(mean_rate, 4)})

useful_df = pd.DataFrame(useful_features).sort_values(by="max_diff", ascending=False).reset_index(drop=True)
useless_df = pd.DataFrame(useless_features).sort_values(by="max_diff", ascending=False).reset_index(drop=True)

print("Top useful variables:")
print(useful_df.head(10))

print("\nSample of less useful variables:")
print(useless_df.head(10))
# Out:
# Top useful variables:
#     feature  max_diff  mean_rate
# 0    GQTYPE    0.5333     0.2149
# 1        GQ    0.3215     0.1705
# 2     NFAMS    0.2800     0.1243
# 3     UNREL    0.2787     0.1193
# 4  EMPSTATD    0.2596     0.0464
# 5      HHWT    0.2537     0.0591
# 6      BIKE    0.2387     0.0951
# 7    TOILET    0.2386     0.0667
# 8      ROOF    0.2386     0.0672
# 9      WALL    0.2386     0.0528
#
# Sample of less useful variables:
#     feature  max_diff  mean_rate
# 0    NCHILD    0.0193     0.0175
# 1  DISABLED    0.0164     0.0184
# 2   DISMNTL    0.0163     0.0189
# 3  LABFORCE    0.0158     0.0283
# 4    MARSTD    0.0157     0.0247
# 5  NATIVITY    0.0157     0.0182
# 6   CONSENS    0.0157     0.0259
# 7    DISEMP    0.0153     0.0241
# 8     MARST    0.0144     0.0257
# 9  RESIDENT    0.0138     0.0320

# %%
pd.crosstab(mig5_data['GQTYPE'], mig5_data['mig_provincial'], normalize='index')
# Out:
# mig_provincial                                             0         1
# GQTYPE
# 1-person unit created by splitting large household  0.745920  0.254080
# Boarding school or student housing                  0.681303  0.318697
# Floating population                                 0.918558  0.081442
# Hospital, nursing home, hospice, or instutions ...  0.950943  0.049057
# Hotel, pension, lodging, or boarding house          0.772059  0.227941
# Military or police institution                      0.434211  0.565789
# NIU (not in universe)                               0.967511  0.032489
# Other group quarters                                0.859447  0.140553
# Prisons, reformatories, or correctional institu...  0.564516  0.435484
# Religious institution, monastery, seminary, or ...  0.842105  0.157895
# Unknown                                             0.899493  0.100507

# %%
pd.crosstab(mig5_data['GQ'], mig5_data['mig_provincial'], normalize='index')
# Out:
# mig_provincial                                             0         1
# GQ
# 1-person unit created by splitting large household  0.745920  0.254080
# Households                                          0.974677  0.025323
# Institutions                                        0.653176  0.346824
# Other group quarters                                0.874257  0.125743
# Unknown/group quarters not identified               0.899493  0.100507

# %% [markdown]
# ### Process Migration Response
