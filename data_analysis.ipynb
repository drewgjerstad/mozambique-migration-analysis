# %% [markdown]
# # Data Analysis
# This is a starter notebook for loading the IPUMS data and perform analyses.

# %%
# Load Dependencies
from pathlib import Path
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# Out:
# True

# %%
# Load Custom Scripts
from src.utils.ipums_extract import (
    get_ipums_data,
    load_ipums_from_pkl,
)

# %% [markdown]
# ## Load IPUMS Dataset

# %%
# Define Parameters (do not push your API key to VCS)
API_KEY = "key"
DOWNLOAD_DIR = Path(r"data")
PKL_EXPORT = True
PKL_PATH = Path(r"data/ipums_extract.pkl")

collection = "ipumsi"
description = "data mining mozambique project"
samples = ["mz1997a", "mz2007a", "mz2017a"]

# %%
# Define Variables
variables = [
    # Tech Households
    "PERSONS",
    # Group Quarters
    "GQ", "GQTYPE", "UNREL",
    # Global Geography
    "URBAN", "POPDENSGEO1", "POPDENSGEO2",
    # National Geography
    "GEO1_MZ", "GEO2_MZ",
    # Household Economic
    "OWNERSHIP",
    # Utilities
    "ELECTRIC", "WATSUP", "PHONE",
    # Appliances
    "AUTOS", "MOTORCYCLE", "BIKE", "COMPUTER", "TV", "RADIO",
    # Dwelling Characteristics
    "ROOMS", "BEDROOMS", "TOILET", "FLOOR", "WALL", "ROOF",
    # Constructed Household
    "HHTYPE", "NFAMS", "NCOUPLES", "NMOTHERS", "NFATHERS",
    # Constructed Family
    "FAMSIZE", "NCHILD", "NCHLT5", "ELDCH", "YNGCH",
    # Demographic
    "RELATE", "AGE", "SEX", "MARST", "CONSENS", 
    # Fertility and Mortality
    "CHBORN", "CHSURV", "CHBORNF", "CHBORNM", "CHSURVF", "CHSURVM", "BIRTHSLYR",
    "BIRTHSURV", "MORTMOT", "MORTFAT",
    # Navity and Birthplace
    "NATIVITY", "CITIZEN", "NATION", "BPL1_MZ", "BPL2_MZ",
    # Ethnicity and Language
    "RELIGION", "RACE", "SPEAKPORT", "LANGMZ", "MTONGMZ", 
    # Education
    "SCHOOL", "LIT", "EDATTAIN",
    # Work
    "EMPSTAT", "LABFORCE", "EMPSECT",
    # Occupation, Industry
    "OCCISCO", "INDGEN",
    # Global Migration - Not giving us any other migration variables,
    # as they would likely be too correlated and uninteresting (AH)
    "MIGRATE1", "MIGRATE5", 
    # Disability
    "DISABLED", "DISEMP", "DISBLND", "DISDEAF", "DISMUTE", "DISLOWR", "DISUPPR",
    "DISMNTL", "DISORIG"
]

# %%
# Get IPUMS Data
ipums_df = get_ipums_data(
    collection=collection,
    description=description,
    samples=samples,
    variables=variables,
    api_key=API_KEY,
    download_dir=DOWNLOAD_DIR,
    pkl_export=PKL_EXPORT,
    pkl_path=PKL_PATH
)
# Out:
# Extract submitted to IPUMS. Extract ID: 2.
# Waiting for extract to finish processing on IPUMS server...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[33], line 2
#       1 # Get IPUMS Data
# ----> 2 ipums_df = get_ipums_data(
#       3     collection=collection,
#       4     description=description,
#       5     samples=samples,
#       6     variables=variables,
#       7     api_key=API_KEY,
#       8     download_dir=DOWNLOAD_DIR,
#       9     pkl_export=PKL_EXPORT,
#      10     pkl_path=PKL_PATH
#      11 )
#
# File c:\Users\Hasan\OneDrive\Desktop\csci5523\umn-fall2025-csci5523-project\src\utils\ipums_extract.py:74, in get_ipums_data(collection, description, samples, variables, api_key, download_dir, pkl_export, pkl_path)
#      72 # Wait for Extract
#      73 print("Waiting for extract to finish processing on IPUMS server...")
# ---> 74 ipums.wait_for_extract(extract)
#      76 # Download Extract
#      77 print(f"Downloading extract to {download_dir} ...")
#
# File c:\Users\Hasan\OneDrive\Desktop\csci5523\umn-fall2025-csci5523-project\venv\Lib\site-packages\ipumspy\api\core.py:409, in IpumsApiClient.wait_for_extract(self, extract, collection, inital_wait_time, max_wait_time, timeout)
#     405     raise IpumsNotFound(
#     406         f"There is no IPUMS extract with extract number {extract_id} in collection {collection}"
#     407     )
#     408 elif status != "completed":
# --> 409     time.sleep(wait_time)
#     410     total_time += wait_time
#     411     wait_time = min(wait_time * 2, max_wait_time)
#
# KeyboardInterrupt:

# %%
# Load from PKL
ipums_df_pkl = load_ipums_from_pkl(PKL_PATH)

# %%
# Transform to fix NIU, unknown and other issues
var_dicts = ''
with open('var_dictionaries.txt', encoding='utf-8') as f:
    exec("var_dicts = " + f.read())

for v in var_dicts.keys():
    ipums_df_pkl[v] = ipums_df_pkl[v].map(lambda x: var_dicts[v].get(x, x))

# %%
# Drop unessecary columnes
ipums_df_pkl.drop(columns=['COUNTRY', 'SAMPLE', 'SERIAL', 'HHWT', 'PERNUM', 'PERWT'], inplace=True)

# %%
# Remove Migration NIUS and unknown
mig1_data = ipums_df_pkl[~ipums_df_pkl['MIGRATE1'].isna()].copy()
mig5_data = ipums_df_pkl[~ipums_df_pkl['MIGRATE5'].isna()].copy()

# Make new variance for prediction
mig1_data['mig_provincial'] = mig1_data['MIGRATE1']
mig5_data['mig_provincial'] = mig5_data['MIGRATE5']

# Rename columns
mig1_data = mig1_data.drop(['MIGRATE1', 'MIGRATE5'], axis=1)
mig5_data = mig5_data.drop(['MIGRATE1', 'MIGRATE5'], axis=1)

# %%
print(mig1_data['mig_provincial'].value_counts(dropna=False))
print(mig5_data['mig_provincial'].value_counts(dropna=False))
# Out:
# mig_provincial
# 0.0    5860462
# 1.0      69067
# Name: count, dtype: int64
# mig_provincial
# 0.0    4746396
# 1.0     228173
# Name: count, dtype: int64

# %% [markdown]
# ## Data Analysis

# %% [markdown]
# ### Value Counts for Each Set
# In this section, we print out the value counts for each column in the sets. This
# will allow us to identify useless (i.e., all the same value) or unique (i.e.,
# will not generalize well) columns for removal.

# %%
for col in mig1_data.columns:
    print(mig1_data[col].value_counts())
    print('-'*30)
# Out:
# YEAR
# 2017    2545554
# 2007    1931544
# 1997    1452431
# Name: count, dtype: int64
# ------------------------------
# PERSONS
# 6     979624
# 5     956894
# 4     888129
# 3     686787
# 7     641334
# 8     468220
# 2     398578
# 9     314093
# 10    152814
# 1     140392
# 11     99157
# 12     67139
# 13     39168
# 14     26461
# 15     18694
# 16     13858
# 17      9780
# 18      7793
# 19      4135
# 20      3105
# 21      2806
# 22      2249
# 24      1468
# 23      1098
# 25      1067
# 26       769
# 27       696
# 28       555
# 30       340
# 29       320
# 31       313
# 35       296
# 32       213
# 36       198
# 39       191
# 34       150
# 44       123
# 33        94
# 47        92
# 45        90
# 37        73
# 50        48
# 48        48
# 41        40
# 38        37
# Name: count, dtype: Int64
# ------------------------------
# GQ
# Households                                            5921521
# Other group quarters                                     2430
# 1-person unit created by splitting large household       2325
# Institutions                                             1875
# Name: count, dtype: int64
# ------------------------------
# GQTYPE
# 1-person unit created by splitting large household                              2325
# Other group quarters                                                            1443
# Floating population                                                              844
# Boarding school or student housing                                               716
# Military or police institution                                                   534
# Hospital, nursing home, hospice, or instutions for persons with disabilities     300
# Prisons, reformatories, or correctional institutions                             168
# Religious institution, monastery, seminary, or convent                           157
# Hotel, pension, lodging, or boarding house                                       143
# Name: count, dtype: int64
# ------------------------------
# UNREL
# 0    5727870
# 1     159823
# 2      24683
# 3       7682
# 4       3477
# 9       2220
# 5       1665
# 6        981
# 7        644
# 8        484
# Name: count, dtype: int64
# ------------------------------
# URBAN
# 0.0    4100523
# 1.0    1828805
# Name: count, dtype: int64
# ------------------------------
# POPDENSGEO1
# 70.21      516948
# 48.64      469693
# 51.82      381628
# 37.83      367474
# 28.44      277828
# 38.61      272480
# 25.38      242277
# 29.02      215269
# 32.01      208824
# 81.62      179204
# 30.12      175302
# 17.81      169543
# 14.03      162806
# 24.33      157669
# 20.92      154763
# 21.13      139471
# 23.34      134197
# 18.44      132638
# 19.13      124213
# 18.69      121006
# 16.70      118600
# 52.08      114888
# 16.12      114267
# 11.55      110508
# 9.52       109953
# 16.68      108283
# 3208.51    106156
# 3095.45    103122
# 14.45      102845
# 2818.73     93669
# 16.04       92778
# 35.31       78778
# 6.26        72449
# Name: count, dtype: int64
# ------------------------------
# POPDENSGEO2
# 2725.889893    97237
# 226.729996     86784
# 92.940002      85747
# 259.790009     75071
# 27.020000      68422
#                ...
# 4.700000        2042
# 1.720000        1919
# 2.710000        1881
# 3.570000        1739
# 2.150000        1399
# Name: count, Length: 343, dtype: int64
# ------------------------------
# GEO1_MZ
# Nampula             1171056
# Zambézia            1114995
# Tete                 522328
# Sofala               490706
# Cabo Delgado         488632
# Manica               402277
# Maputo               372870
# Inhambane            368760
# Gaza                 349750
# Niassa               345208
# Cidade de Maputo     302947
# Name: count, dtype: int64
# ------------------------------
# GEO2_MZ
# Cidade da Matola                                               202536
# Cidade de Nampula, Rapale                                      191880
# Beira, Dondo                                                   180655
# Xai-Xai, Bilene, Mandlakazi, Limpopo, Chongoene                179257
# Milange, Molumbo                                               165198
# Quelimane, Inhassunge, Nicoadala                               150450
# Cidade de Tete, Cahora-Bassa, Changara, Mágoè, Marara          143434
# Gondola, Manica, Macate, Vanduzi                               134171
# Monapo, Nacala-à-Velha                                         115065
# Morrumbala, Derre                                              103565
# Ilha de Moçambique, Mossuril, Nacala-Porto                     100587
# Angónia                                                         97112
# Moma, Larde                                                     92943
# Balama, Montepuez                                               91486
# Gúruè                                                           86050
# Mocuba                                                          85911
# Urbano 4 (KaMavota)                                             82074
# Angoche                                                         81736
# Erati                                                           80595
# Urbano 5 (KaMubukwana)                                          78939
# Machaze, Mossurize                                              78584
# Mogovolas                                                       77901
# Ile, Mulevala                                                   77858
# Alto Molocué                                                    75789
# Maganja da Costa, Mocubela                                      73164
# Chimoio                                                         73089
# Memba                                                           71020
# Inharrime, Zavala                                               67919
# Lichinga, Chimbonila                                            66274
# Chiúre                                                          66267
# Urbano 3 (KaMaxakeni)                                           60914
# Muecate, Nacaroa                                                60279
# Mueda, Muidumbe                                                 59758
# Nhamatanda                                                      59484
# Massinga                                                        58833
# Mutarara, Doa                                                   56190
# Gorongosa, Maringué                                             56052
# Moatize                                                         55898
# Chibuto                                                         54844
# Cuamba                                                          54566
# Chókwè                                                          54477
# Ribáuè                                                          54437
# Namacurra                                                       53912
# Namuno                                                          53613
# Pebane                                                          50193
# Gilé                                                            48559
# Malema                                                          48383
# Meconta                                                         47924
# Mecanhelas                                                      47537
# Manhiça                                                         47096
# Tsangano                                                        47051
# Mecubúri                                                        45788
# Búzi                                                            45297
# Urbano 2 (Nlhamankulu)                                          42475
# Mandimba                                                        40797
# Murrupula                                                       40752
# Cidade de Pemba                                                 40395
# Lugela                                                          40158
# Mogincual, Luipo                                                39086
# Urbano 1 (KaMpfumo), Urbano 6 (KaTembe), Urbano 7 (KaNyaka)     38545
# Vilankulo                                                       38304
# Barué                                                           38270
# Chinde, Luabo                                                   37573
# Sussundenga                                                     37499
# Morrumbene                                                      35389
# Boane                                                           34798
# Namarroi                                                        34603
# Caia                                                            34553
# Ancuabe                                                         33815
# Marromeu                                                        32734
# Marracuene                                                      32049
# Mopeia                                                          32012
# Mecúfi, Metuge                                                  31911
# Cidade de Maxixe                                                31832
# Macanga                                                         30285
# Homoine                                                         30251
# Chibabava                                                       29848
# Chifunde                                                        29517
# Guro, Macossa                                                   28253
# Mocímboa da Praia                                               27803
# Marrupa, Mecula, Mavago                                         26855
# Jangamo                                                         26693
# Macomia                                                         25597
# Marávia                                                         25109
# Lago                                                            22954
# Lalaua                                                          22680
# Chicualacuala, Chigubo, Mapai, Massangena                       21945
# Guijá                                                           21666
# Chiúta                                                          21433
# Nangade                                                         20029
# Cidade de Inhambane                                             19025
# Chemba                                                          18893
# Moamba                                                          18163
# N'gauma                                                         18136
# Sanga                                                           16887
# Zumbo                                                           16299
# Palma                                                           15239
# Maúa                                                            15087
# Magude                                                          15067
# Machanga                                                        14958
# Ibo, Quissanga                                                  14639
# Inhassoro                                                       14145
# Panda                                                           13063
# Mabote                                                          12830
# Tambara                                                         12411
# Namaacha                                                        11956
# Matutuine                                                       11205
# Cheringoma                                                      10725
# Funhalouro                                                      10707
# Nipepe                                                           9967
# Govuro                                                           9769
# Metarica                                                         9078
# Mabalane                                                         9051
# Muembe                                                           8555
# Majune                                                           8515
# Massingir                                                        8510
# Meluco                                                           8080
# Muanza                                                           7507
# Name: count, dtype: int64
# ------------------------------
# OWNERSHIP
# 1.0    4101543
# 0.0     356732
# Name: count, dtype: int64
# ------------------------------
# OWNERSHIPD
# Owned                           4101543
# Renting, not specified           196241
# Free/usufruct (no cash rent)     123258
# Not owned, other                  37233
# Name: count, dtype: int64
# ------------------------------
# ELECTRIC
# 0.0    4855794
# 1.0    1022786
# Name: count, dtype: int64
# ------------------------------
# WATSUP
# No piped water                               4384590
# Have access to public piped water             558820
# Piped within the building or plot of land     322416
# Piped outside the dwelling                    280231
# Piped inside dwelling                         209057
# Piped, shared with other households           167901
# Name: count, dtype: int64
# ------------------------------
# PHONE
# 0.0    4407363
# 1.0      67638
# Name: count, dtype: int64
# ------------------------------
# AUTOS
# 0.0    4309730
# 1.0     165279
# Name: count, dtype: int64
# ------------------------------
# MOTORCYCLE
# 0.0    4218138
# 1.0     256861
# Name: count, dtype: int64
# ------------------------------
# BIKE
# 0.0    2932357
# 1.0    1542825
# Name: count, dtype: int64
# ------------------------------
# COMPUTER
# 0.0    4311687
# 1.0     163304
# Name: count, dtype: int64
# ------------------------------
# TV
# 0.0    3637003
# 1.0     838092
# Name: count, dtype: int64
# ------------------------------
# RADIO
# 0.0    3399245
# 1.0    2488559
# Name: count, dtype: int64
# ------------------------------
# ROOMS
# 2.0     1823734
# 3.0     1448280
# 1.0     1267659
# 4.0     1164035
# 5.0      139114
# 6.0       41806
# 7.0       17656
# 8.0        9770
# 9.0        5414
# 10.0       2722
# 11.0       1001
# 12.0        849
# 13.0        350
# 14.0        211
# 16.0        154
# 15.0         85
# 20.0         79
# 19.0         36
# 17.0         30
# 18.0         30
# Name: count, dtype: int64
# ------------------------------
# BEDROOMS
# 1.0     2642518
# 2.0     2117510
# 3.0      882633
# 4.0      229758
# 5.0       31279
# 6.0       10988
# 7.0        3988
# 8.0        1865
# 9.0        1044
# 10.0        761
# 11.0        205
# 12.0        162
# 13.0        156
# 15.0        109
# 14.0         39
# Name: count, dtype: int64
# ------------------------------
# TOILET
# Non-flush, latrine                  3071681
# No toilet                           2442753
# Flush toilet                         279299
# Non-flush, other and unspecified     129234
# Name: count, dtype: int64
# ------------------------------
# FLOOR
# None/unfinished (earth)    3127080
# Cement                     1189601
# Tile                         85128
# Wood                         35572
# Other finished, n.e.c.       32284
# Marble                        5293
# Name: count, dtype: int64
# ------------------------------
# WALL
# Mud with wood/wattle                   1867898
# Adobe                                  1617814
# Reed, bamboo, or palm                   930565
# Cement blocks                           893085
# Brick                                   455104
# Wood, fibercement, zinc, or plywood      99786
# Other material                           54855
# Plastic sheeting, cardboard               3896
# Name: count, dtype: int64
# ------------------------------
# ROOF
# Thatch (straw, grass, leaves, palm, etc.)    3730276
# Zinc or tin                                  1886511
# Asbestos                                      141497
# Reinforced concrete (slab)                     94962
# Other, unspecified                             49598
# Tile, unspecified material                     12555
# Tile or cement                                  7604
# Name: count, dtype: int64
# ------------------------------
# HHTYPE
# Married/cohab couple with children               2419390
# Extended family, relatives only                  2167380
# Single-parent family                              661478
# Married/cohab couple, no children                 217894
# Composite household, family and non-relatives     181851
# One-person household                              137763
# Polygamous family                                  64425
# Non-family household                                9079
# Group quarters                                      4305
# Name: count, dtype: int64
# ------------------------------
# NFAMS
# 1    5737071
# 2     154501
# 3      23228
# 4       7002
# 5       2829
# 9       2328
# 6       1387
# 7        773
# 8        410
# Name: count, dtype: int64
# ------------------------------
# NCOUPLES
# 1    4179024
# 0    1565794
# 2     158045
# 3      22063
# 4       3885
# 5        493
# 6        177
# 7         48
# Name: count, dtype: int64
# ------------------------------
# NMOTHERS
# 1    4285402
# 0     901078
# 2     581010
# 3     123383
# 4      28352
# 5       7077
# 6       2120
# 7        684
# 8        263
# 9        160
# Name: count, dtype: int64
# ------------------------------
# NFATHERS
# 1    3883699
# 0    1889611
# 2     136049
# 3      17246
# 4       2489
# 5        310
# 6        125
# Name: count, dtype: int64
# ------------------------------
# RESIDENT
# Present resident    5754489
# Absent resident      175040
# Name: count, dtype: int64
# ------------------------------
# FAMSIZE
# 6     969044
# 5     957477
# 4     890400
# 3     690360
# 7     636081
# 8     460625
# 2     402746
# 9     304106
# 1     180905
# 10    148710
# 11     95776
# 12     64187
# 13     37477
# 14     25687
# 15     17782
# 16     13169
# 17      9206
# 18      7175
# 19      3967
# 20      2901
# 21      2664
# 22      1964
# 24      1314
# 23      1140
# 25      1074
# 27       637
# 26       622
# 28       423
# 29       373
# 31       313
# 30       170
# 32       152
# 47       139
# 36       137
# 35       127
# 34        97
# 33        91
# 44        80
# 38        75
# 45        45
# 41        40
# 37        36
# 39        35
# Name: count, dtype: int64
# ------------------------------
# NCHILD
# 0    4019086
# 1     553090
# 2     439260
# 3     351532
# 4     272974
# 5     152305
# 6      82871
# 7      36932
# 8      12763
# 9       8716
# Name: count, dtype: int64
# ------------------------------
# NCHLT5
# 0    4680149
# 1     772837
# 2     413487
# 3      55652
# 4       6222
# 5        879
# 6        197
# 7         67
# 8         27
# 9         12
# Name: count, dtype: int64
# ------------------------------
# ELDCH
# 6.0     94998
# 4.0     94998
# 10.0    92658
# 7.0     92299
# 12.0    92077
# 3.0     91983
# 5.0     89211
# 1.0     88614
# 2.0     86847
# 15.0    83486
# 8.0     79720
# 14.0    79186
# 9.0     78877
# 0.0     77511
# 13.0    77285
# 11.0    71084
# 17.0    69378
# 16.0    67564
# 18.0    62302
# 20.0    46930
# 19.0    45592
# 22.0    31581
# 21.0    30251
# 23.0    23617
# 25.0    20339
# 24.0    18846
# 27.0    13837
# 26.0    13585
# 28.0    11273
# 30.0    11073
# 29.0     9071
# 32.0     7491
# 50.0     6981
# 31.0     6344
# 35.0     5465
# 33.0     4706
# 34.0     4451
# 37.0     3802
# 36.0     3599
# 38.0     3136
# 40.0     3025
# 39.0     2841
# 42.0     2267
# 41.0     1949
# 45.0     1604
# 43.0     1558
# 47.0     1229
# 44.0     1121
# 46.0     1023
# 48.0      951
# 49.0      827
# Name: count, dtype: int64
# ------------------------------
# YNGCH
# 1.0     342572
# 0.0     314138
# 2.0     283533
# 3.0     187424
# 4.0     121713
# 5.0      86838
# 6.0      71660
# 7.0      62587
# 8.0      47099
# 10.0     43424
# 9.0      39424
# 12.0     35235
# 11.0     30652
# 13.0     27247
# 14.0     24399
# 15.0     23835
# 17.0     17817
# 16.0     17392
# 18.0     15859
# 20.0     11872
# 19.0     11071
# 22.0      8551
# 21.0      7849
# 23.0      7041
# 25.0      6760
# 50.0      5913
# 24.0      5670
# 27.0      4788
# 30.0      4624
# 26.0      4199
# 28.0      4194
# 32.0      3589
# 29.0      3526
# 35.0      2836
# 31.0      2632
# 33.0      2255
# 34.0      2243
# 37.0      2211
# 40.0      1845
# 38.0      1812
# 36.0      1798
# 39.0      1708
# 42.0      1442
# 45.0      1147
# 41.0      1110
# 43.0      1099
# 47.0       962
# 44.0       791
# 48.0       735
# 46.0       668
# 49.0       654
# Name: count, dtype: int64
# ------------------------------
# RELATE
# Child             2734855
# Head              1418398
# Spouse/partner     900781
# Other relative     832832
# Non-relative        42462
# Name: count, dtype: int64
# ------------------------------
# RELATED
# Biological child                            2011496
# Head                                        1418398
# Spouse/partner                               900781
# Child                                        630642
# Other relative, not elsewhere classified     406009
# Grandchild                                   338574
# Stepchild                                     72109
# Child-in-law                                  57767
# Non-relative                                  42462
# Parent                                        30482
# Adopted child                                 20608
# Name: count, dtype: int64
# ------------------------------
# AGE
# 3.0      237397
# 4.0      236069
# 2.0      223665
# 6.0      215604
# 5.0      212441
# 1.0      212294
# 7.0      204621
# 10.0     182100
# 8.0      174718
# 12.0     166176
# 9.0      161867
# 20.0     145830
# 18.0     136674
# 11.0     136414
# 13.0     135935
# 15.0     135730
# 14.0     131151
# 17.0     127014
# 22.0     119806
# 16.0     115304
# 19.0     114681
# 25.0     113814
# 23.0     105928
# 30.0     104637
# 27.0      95893
# 21.0      92962
# 28.0      90490
# 24.0      87330
# 32.0      85458
# 35.0      80772
# 29.0      75928
# 26.0      72773
# 37.0      68522
# 40.0      67376
# 38.0      60329
# 33.0      59001
# 31.0      56885
# 42.0      55923
# 39.0      55868
# 34.0      53598
# 45.0      52633
# 36.0      48922
# 47.0      46416
# 43.0      44436
# 50.0      42122
# 48.0      36836
# 41.0      36652
# 49.0      34209
# 52.0      33386
# 57.0      31161
# 44.0      30733
# 60.0      29426
# 46.0      28846
# 53.0      28597
# 55.0      28237
# 51.0      25901
# 54.0      23025
# 58.0      21733
# 67.0      21572
# 56.0      20870
# 62.0      19672
# 59.0      19022
# 65.0      18753
# 63.0      16018
# 70.0      14654
# 61.0      14081
# 64.0      13405
# 68.0      13247
# 69.0      10910
# 66.0      10367
# 77.0      10307
# 72.0      10167
# 75.0       9287
# 73.0       6924
# 71.0       6640
# 80.0       6353
# 78.0       6182
# 74.0       5605
# 76.0       5165
# 79.0       4586
# 87.0       3730
# 82.0       3675
# 85.0       3213
# 81.0       2666
# 83.0       2597
# 84.0       1987
# 0.0        1905
# 90.0       1750
# 89.0       1669
# 86.0       1640
# 88.0       1423
# 100.0      1293
# 92.0        863
# 97.0        778
# 99.0        775
# 95.0        767
# 93.0        662
# 91.0        624
# 98.0        614
# 94.0        434
# 96.0        428
# Name: count, dtype: int64
# ------------------------------
# SEX
# 0    3085867
# 1    2843662
# Name: count, dtype: int64
# ------------------------------
# MARST
# Single/never married                3454507
# Married/in union                    2140231
# Widowed                              171267
# Separated/divorced/spouse absent     142098
# Name: count, dtype: int64
# ------------------------------
# MARSTD
# Single/never married     3454507
# Consensual union         1596873
# Married, formally         543358
# Widowed                   171267
# Separated or divorced     142098
# Name: count, dtype: int64
# ------------------------------
# CONSENS
# 1.0    1596873
# 0.0     543358
# Name: count, dtype: int64
# ------------------------------
# CHBORN
# 0.0     549397
# 1.0     229985
# 2.0     201901
# 3.0     165580
# 4.0     140526
# 5.0     107069
# 6.0      81859
# 7.0      58504
# 8.0      42332
# 9.0      27519
# 10.0     20413
# 11.0      9309
# 12.0      7301
# 13.0      2524
# 14.0       305
# 15.0       177
# 18.0        73
# 16.0        72
# 17.0        32
# Name: count, dtype: int64
# ------------------------------
# CHSURV
# 1.0     244629
# 2.0     218046
# 3.0     178186
# 4.0     146853
# 5.0     104808
# 6.0      71741
# 7.0      42739
# 8.0      23029
# 0.0      10552
# 9.0      10257
# 10.0      5125
# 11.0       549
# 12.0       250
# 14.0       147
# 13.0        56
# Name: count, dtype: int64
# ------------------------------
# CHBORNF
# 0.0     723974
# 1.0     345997
# 2.0     235150
# 3.0     146422
# 4.0      84762
# 5.0      44285
# 6.0      22145
# 7.0      10256
# 8.0       4426
# 9.0       1955
# 10.0       716
# 11.0       309
# 12.0       158
# 13.0        95
# Name: count, dtype: int64
# ------------------------------
# CHBORNM
# 0.0     722092
# 1.0     345864
# 2.0     237047
# 3.0     148408
# 4.0      85437
# 5.0      44320
# 6.0      20796
# 7.0       9367
# 8.0       4024
# 9.0       1648
# 10.0       631
# 11.0       276
# 12.0       110
# 13.0        84
# Name: count, dtype: int64
# ------------------------------
# CHSURVF
# 0.0     557630
# 1.0     365795
# 2.0     236295
# 3.0     134095
# 4.0      64865
# 5.0      26244
# 6.0       9340
# 7.0       3274
# 8.0        949
# 9.0        390
# 10.0       126
# 11.0        99
# 12.0        60
# Name: count, dtype: int64
# ------------------------------
# CHSURVM
# 0.0     563830
# 1.0     363935
# 2.0     236990
# 3.0     132512
# 4.0      63313
# 5.0      25482
# 6.0       8335
# 7.0       2851
# 8.0        758
# 9.0        309
# 12.0       103
# 10.0        99
# 11.0        62
# Name: count, dtype: int64
# ------------------------------
# BIRTHSLYR
# 0.0    838575
# 1.0    204453
# 2.0     10913
# 4.0     10250
# 3.0      4591
# Name: count, dtype: int64
# ------------------------------
# BIRTHSURV
# 0.0    551294
# 1.0    189062
# 2.0      9392
# 4.0      9282
# 3.0      4108
# Name: count, dtype: int64
# ------------------------------
# MORTMOT
# 0.0    4357582
# 1.0    1288518
# Name: count, dtype: int64
# ------------------------------
# MORTFAT
# 0.0    2993322
# 1.0    1422305
# Name: count, dtype: int64
# ------------------------------
# NATIVITY
# 1.0    5826650
# 0.0      86331
# Name: count, dtype: int64
# ------------------------------
# CITIZEN
# 1.0    5810019
# 0.0      35590
# Name: count, dtype: int64
# ------------------------------
# NATION
# Mozambique                      5810019
# Malawi                            13960
# South Africa                       5167
# Zimbabwe                           4501
# Other countries n.s.               2917
# Tanzania                           2037
# Portugal                           1609
# Cape Verde                          951
# Zambia                              864
# India                               596
# Lesotho                             372
# Congo (Republic of)                 237
# Africa, other or n.s.               224
# Europe, other or n.s.               193
# Pakistan                            193
# Democratic Republic of Congo        178
# Angola                              174
# Sao Tome and Principe               157
# Brazil                              130
# United Kingdom                       92
# Burundi                              90
# Italy                                88
# China                                87
# Nigeria                              81
# Swaziland                            77
# Guinea                               72
# Namibia                              63
# United States                        59
# Rwanda                               48
# Americas, other or n.s.              48
# Chile                                46
# Sierra Leone                         37
# Kenya                                36
# Cuba                                 32
# Spain                                29
# France                               29
# Guinea-Bissau                        28
# Senegal                              26
# Equatorial Guinea                    26
# Togo                                 25
# South America, other or n.s.          8
# Asia, other or n.s.                   3
# Name: count, dtype: int64
# ------------------------------
# BPL1_MZ
# Nampula             1125631
# Zambézia            1104982
# Tete                 485264
# Cabo Delgado         468780
# Sofala               467411
# Inhambane            421202
# Gaza                 393989
# Manica               354186
# Niassa               319110
# Maputo               244502
# Cidade de Maputo     236655
# Foreign Country       91903
# Name: count, dtype: int64
# ------------------------------
# BPL2_MZ
# Xai-Xai, Bilene, Mandlakazi, Limpopo, Chongoene                194598
# Milange, Molumbo                                               145777
# Quelimane, Inhassunge, Nicoadala                               134570
# Cidade de Nampula, Rapale                                      134450
# Beira, Dondo                                                   130778
# Cidade de Tete, Cahora-Bassa, Changara, Mágoè, Marara          123471
# Cidade da Matola                                               116757
# Gondola, Manica, Macate, Vanduzi                               105210
# Monapo, Nacala-à-Velha                                          99889
# Morrumbala, Derre                                               97781
# Abroad                                                          91903
# Angónia                                                         89805
# Moma, Larde                                                     87748
# Ile, Mulevala                                                   86524
# Angoche                                                         84466
# Ilha de Moçambique, Mossuril, Nacala-Porto                      83382
# Balama, Montepuez                                               82397
# Erati                                                           81002
# Gúruè                                                           79914
# Maganja da Costa, Mocubela                                      76971
# Mogovolas                                                       76557
# Alto Molocué                                                    76210
# Mocuba                                                          75302
# Chibuto                                                         73758
# Memba                                                           73740
# Massinga                                                        72550
# Machaze, Mossurize                                              72463
# Inharrime, Zavala                                               70984
# Chiúre                                                          67575
# Mutarara, Doa                                                   60895
# Mueda, Muidumbe                                                 58641
# Gorongosa, Maringué                                             57330
# Muecate, Nacaroa                                                56823
# Murrupula                                                       56370
# Búzi                                                            56217
# Chimoio                                                         55761
# Namacurra                                                       54443
# Ribáuè                                                          54191
# Lichinga, Chimbonila                                            54157
# Namuno                                                          52580
# Chókwè                                                          51407
# Moatize                                                         50500
# Pebane                                                          49507
# Malema                                                          46933
# Gilé                                                            46879
# Vilankulo                                                       46139
# Manhiça                                                         45918
# Cuamba                                                          44638
# Mecubúri                                                        44561
# Mecanhelas                                                      43106
# Chinde, Luabo                                                   41898
# Meconta                                                         40879
# Lugela                                                          39419
# Caia                                                            38955
# Tsangano                                                        38819
# Mogincual, Luipo                                                37731
# Morrumbene                                                      37199
# Nhamatanda                                                      36610
# Namarroi                                                        34952
# Sussundenga                                                     34372
# Chibabava                                                       33211
# Marromeu                                                        32535
# Ancuabe                                                         31359
# Mandimba                                                        31302
# Barué                                                           31119
# Homoine                                                         31089
# Guro, Macossa                                                   30409
# Mopeia                                                          29633
# Jangamo                                                         29130
# Mecúfi, Metuge                                                  28577
# Cidade de Pemba                                                 26059
# Marrupa, Mecula, Mavago                                         25794
# Macomia                                                         24985
# Macanga                                                         24866
# Mocímboa da Praia                                               24357
# Chemba                                                          23797
# Marávia                                                         23686
# Chifunde                                                        22803
# Chiúta                                                          22561
# Lago                                                            22163
# Guijá                                                           22028
# Lalaua                                                          21865
# Chicualacuala, Chigubo, Mapai, Massangena                       21214
# Urbano 4 (KaMavota)                                             20301
# Cidade de Maxixe                                                20032
# Cidade de Inhambane                                             19957
# Urbano 5 (KaMubukwana)                                          19619
# Marracuene                                                      18763
# Nangade                                                         18368
# Machanga                                                        17465
# Panda                                                           17049
# Maúa                                                            16708
# Boane                                                           16013
# Magude                                                          15545
# Sanga                                                           15238
# N'gauma                                                         15049
# Zumbo                                                           14972
# Mabote                                                          14050
# Ibo, Quissanga                                                  13973
# Tambara                                                         13803
# Inhassoro                                                       13645
# Palma                                                           12628
# Funhalouro                                                      12583
# Urbano 3 (KaMaxakeni)                                           12553
# Moamba                                                          11904
# Cheringoma                                                      11818
# Govuro                                                          10904
# Nipepe                                                          10665
# Majune                                                           9655
# Metarica                                                         8990
# Matutuine                                                        8608
# Urbano 2 (Nlhamankulu)                                           8039
# Meluco                                                           8010
# Mabalane                                                         7824
# Muembe                                                           7732
# Massingir                                                        7493
# Namaacha                                                         6435
# Urbano 1 (KaMpfumo), Urbano 6 (KaTembe), Urbano 7 (KaNyaka)      6210
# Muanza                                                           6053
# Name: count, dtype: int64
# ------------------------------
# RELIGION
# Christian      2331478
# Muslim          816199
# No religion     700596
# Other           302085
# Name: count, dtype: int64
# ------------------------------
# RELIGIOND
# Catholic (Roman or unspecified)    1223881
# Muslim                              816199
# No religion                         700596
# Zion Christian                      498039
# Other                               302085
# Anglican                             67616
# Name: count, dtype: int64
# ------------------------------
# RACE
# Black         5776291
# Mixed race      27192
# White            4928
# Indian           4069
# Other            1145
# Pakistani         740
# Chinese           155
# Name: count, dtype: int64
# ------------------------------
# SPEAKPORT
# 0.0    2680888
# 1.0    2336226
# Name: count, dtype: int64
# ------------------------------
# LANGMZ
# Emakhuwa                  981988
# Portuguese                566293
# Xitsonga or Xichangana    362220
# Other languages           351410
# Elomwe                    267549
# Sena                      266094
# Cinyanja                  215801
# Cindau                    149326
# Xitswa                    139464
# Echuwabo                  138151
# Cicopi                     54100
# Cinyungwe                  45006
# Ciyao                      33274
# Shimakonde                 26555
# Chitewe                    26033
# Xirhonga                   22166
# Bitonga or Gitonga         18419
# Cishona                    16493
# Cibalke                    11563
# Kimwani                     8005
# Coti                        6079
# Kiswahili                   2648
# Isizulo                      691
# Cinsenga                     476
# Isiswazi                     190
# Sena Care                     78
# Ekarungu                      76
# Citonga                       50
# Cingoni                       47
# Ciqwaka                       47
# Cindonje                      46
# Gombe                         42
# Tonga                         41
# Xilwandle                     38
# Cicewa                        35
# Ecocti                        34
# Merenje                       32
# Xikalanga                     30
# Phondzo                       26
# Xidzivi                       25
# Name: count, dtype: int64
# ------------------------------
# MTONGMZ
# Emakhuwa                  975414
# Portuguese                530914
# Other languages           378969
# Xitsonga or Xichangana    352515
# Sena                      274947
# Elomwe                    267865
# Cinyanja                  211731
# Cindau                    154478
# Echuwabo                  153986
# Xitswa                    150421
# Cinyungwe                  46203
# Ciyao                      34027
# Cichopi                    30773
# Shimakonde                 27564
# Chitewe                    25940
# Xirhonga                   23562
# Bitonga or Gitonga         22892
# Cishona                    17349
# Cibalke                    10695
# Kimwani                     7629
# Coti                        6024
# Kiswahili                   2175
# Isizulo                     1279
# Cinsenga                     494
# Isiswazi                     392
# Cikhambani                   143
# Cilenje                       78
# Ekarungu                      66
# Citonga                       64
# Sutho                         59
# Cingoni                       53
# Cindonje                      51
# Sena Care                     44
# Xikalanga                     42
# Merenje                       40
# Gombe                         38
# Phondzo                       37
# Cilambwe                      35
# Ciqwaka                       31
# Tonga                         27
# Xilwandle                     27
# Cicewa                        25
# Name: count, dtype: int64
# ------------------------------
# SCHOOL
# No, never attended          2171806
# No, attended in the past    1572499
# Yes                         1323254
# Name: count, dtype: int64
# ------------------------------
# LIT
# 0.0    2729967
# 1.0    2308348
# Name: count, dtype: int64
# ------------------------------
# EDATTAIN
# Less than primary completed    4114908
# Primary completed               895301
# Secondary completed             122269
# University completed             23976
# Name: count, dtype: int64
# ------------------------------
# EDATTAIND
# No schooling                            2481563
# Some primary completed                  1633345
# Primary (6 yrs) completed                698014
# Lower secondary general completed        189096
# Secondary, general track completed        97143
# University completed                      23976
# Secondary, technical track completed      19038
# Lower secondary technical completed        8191
# Some college completed                     6088
# Name: count, dtype: int64
# ------------------------------
# EMPSTAT
# Employed      2254116
# Inactive      2253297
# Unemployed      34426
# Name: count, dtype: int64
# ------------------------------
# EMPSTATD
# At work                                        2023951
# In school                                       986552
# Housework                                       728664
# Inactive, other reasons                         439164
# At work, family holding, not specified          128935
# Have job, not at work in reference period        98510
# Health reasons, unable to work, or disabled      78812
# Unemployed, new worker                           21223
# Retirees and living on rent                      20105
# Unemployed, experienced worker                   13203
# Armed forces                                      2720
# Name: count, dtype: int64
# ------------------------------
# LABFORCE
# 0.0    2051983
# 1.0    1219862
# Name: count, dtype: int64
# ------------------------------
# EMPSECT
# Individual/family enterprise, and self-employed        2038909
# Private, not elsewhere classified                       127617
# Public                                                   79799
# Mixed: public-private or parastatal                      17033
# Foreign government or non-governmental organization       5475
# Collective or cooperative                                 3221
# Name: count, dtype: int64
# ------------------------------
# OCCISCO
# Skilled agricultural and fishery workers      1736819
# Service workers and shop and market sales      187443
# Crafts and related trades workers              123417
# Elementary occupations                          83287
# Technicians and associate professionals         38228
# Plant and machine operators and assemblers      36933
# Professionals                                   26593
# Clerks                                          15926
# Legislators, senior officials and managers       8815
# Armed forces                                     1048
# Name: count, dtype: int64
# ------------------------------
# INDGEN
# Agriculture, fishing, and forestry              1700200
# Wholesale and retail trade                       208044
# Manufacturing                                     63793
# Public administration and defense                 46409
# Construction                                      46096
# Transportation, storage, and communications       27179
# Education                                         24834
# Private household services                        22039
# Other services                                    16281
# Business services and real estate                 14837
# Mining and extraction                             14354
# Health and social work                            11543
# Hotels and restaurants                             7489
# Electricity, gas, water and waste management       2824
# Financial services and insurance                   2216
# Other industry, n.e.c.                              876
# Name: count, dtype: int64
# ------------------------------
# DISABLED
# 0.0    5777200
# 1.0     145637
# Name: count, dtype: int64
# ------------------------------
# DISEMP
# 0.0    3742063
# 1.0      78812
# Name: count, dtype: int64
# ------------------------------
# DISBLND
# 0.0    4459047
# 1.0      18051
# Name: count, dtype: int64
# ------------------------------
# DISDEAF
# 0.0    4461514
# 1.0      15584
# Name: count, dtype: int64
# ------------------------------
# DISMUTE
# 0.0    4102552
# 1.0       7550
# Name: count, dtype: int64
# ------------------------------
# DISLOWR
# 0.0    4448015
# 1.0      29083
# Name: count, dtype: int64
# ------------------------------
# DISUPPR
# 0.0    4467553
# 1.0       9545
# Name: count, dtype: int64
# ------------------------------
# DISMNTL
# 0.0    5907088
# 1.0      15749
# Name: count, dtype: int64
# ------------------------------
# DISORIG
# Disease                    52809
# Congenital, since birth    35561
# Other cause, n.e.c.         9865
# Work accident               6320
# Other                       6221
# Transport accident          4279
# War injury                  1021
# Multiple causes              820
# Name: count, dtype: int64
# ------------------------------
# mig_provincial
# 0.0    5860462
# 1.0      69067
# Name: count, dtype: int64
# ------------------------------

# %%
for col in mig5_data.columns:
    print(mig5_data[col].value_counts())
    print('-'*30)
# Out:
# YEAR
# 2017    2122246
# 2007    1617537
# 1997    1234786
# Name: count, dtype: int64
# ------------------------------
# PERSONS
# 6     805890
# 5     777675
# 4     714101
# 3     577308
# 7     534657
# 8     394412
# 2     377002
# 9     266751
# 1     139068
# 10    130368
# 11     84665
# 12     57273
# 13     33300
# 14     22402
# 15     15811
# 16     11717
# 17      8266
# 18      6541
# 19      3466
# 20      2606
# 21      2334
# 22      1909
# 24      1235
# 23       929
# 25       871
# 26       658
# 27       593
# 28       468
# 30       290
# 29       270
# 31       265
# 35       261
# 39       180
# 32       180
# 36       172
# 34       137
# 44       108
# 33        87
# 47        75
# 37        67
# 50        49
# 45        47
# 48        41
# 41        33
# 38        31
# Name: count, dtype: Int64
# ------------------------------
# GQ
# Households                                            4967152
# 1-person unit created by splitting large household       2267
# Other group quarters                                     2187
# Institutions                                             1779
# Name: count, dtype: int64
# ------------------------------
# GQTYPE
# 1-person unit created by splitting large household                              2267
# Other group quarters                                                            1302
# Floating population                                                              749
# Boarding school or student housing                                               706
# Military or police institution                                                   532
# Hospital, nursing home, hospice, or instutions for persons with disabilities     265
# Religious institution, monastery, seminary, or convent                           152
# Hotel, pension, lodging, or boarding house                                       136
# Prisons, reformatories, or correctional institutions                             124
# Name: count, dtype: int64
# ------------------------------
# UNREL
# 0    4799657
# 1     137866
# 2      21587
# 3       6819
# 4       3051
# 9       2164
# 5       1470
# 6        907
# 7        590
# 8        458
# Name: count, dtype: int64
# ------------------------------
# URBAN
# 0.0    3396668
# 1.0    1577743
# Name: count, dtype: int64
# ------------------------------
# POPDENSGEO1
# 70.21      422009
# 48.64      384971
# 51.82      315673
# 37.83      299462
# 28.44      230659
# 38.61      229119
# 25.38      201865
# 29.02      179329
# 32.01      176531
# 81.62      150111
# 30.12      146460
# 17.81      139889
# 24.33      133219
# 14.03      132428
# 20.92      129895
# 21.13      121799
# 18.44      115050
# 23.34      112112
# 19.13      105596
# 18.69      104192
# 16.70      101995
# 52.08      100708
# 16.12       98725
# 3208.51     95226
# 16.68       94212
# 11.55       92618
# 3095.45     91693
# 14.45       89662
# 9.52        88436
# 2818.73     82993
# 16.04       78544
# 35.31       69182
# 6.26        60206
# Name: count, dtype: int64
# ------------------------------
# POPDENSGEO2
# 2725.889893    83017
# 226.729996     72583
# 92.940002      69255
# 259.790009     64920
# 27.020000      57826
#                ...
# 4.700000        1691
# 1.720000        1611
# 2.710000        1561
# 3.570000        1389
# 2.150000        1138
# Name: count, Length: 343, dtype: int64
# ------------------------------
# GEO1_MZ
# Nampula             966801
# Zambézia            915092
# Tete                434372
# Sofala              415346
# Cabo Delgado        411219
# Manica              337116
# Inhambane           320203
# Maputo              320001
# Gaza                303437
# Niassa              281070
# Cidade de Maputo    269912
# Name: count, dtype: int64
# ------------------------------
# GEO2_MZ
# Cidade da Matola                                               175526
# Cidade de Nampula, Rapale                                      162295
# Beira, Dondo                                                   157716
# Xai-Xai, Bilene, Mandlakazi, Limpopo, Chongoene                156381
# Milange, Molumbo                                               133618
# Quelimane, Inhassunge, Nicoadala                               128464
# Cidade de Tete, Cahora-Bassa, Changara, Mágoè, Marara          121233
# Gondola, Manica, Macate, Vanduzi                               113132
# Monapo, Nacala-à-Velha                                          94709
# Ilha de Moçambique, Mossuril, Nacala-Porto                      84458
# Morrumbala, Derre                                               83113
# Angónia                                                         81769
# Balama, Montepuez                                               76533
# Moma, Larde                                                     76248
# Urbano 4 (KaMavota)                                             72528
# Mocuba                                                          70911
# Gúruè                                                           70549
# Urbano 5 (KaMubukwana)                                          69826
# Angoche                                                         67655
# Erati                                                           66144
# Machaze, Mossurize                                              65659
# Mogovolas                                                       64024
# Ile, Mulevala                                                   63196
# Chimoio                                                         62439
# Alto Molocué                                                    61526
# Maganja da Costa, Mocubela                                      59838
# Inharrime, Zavala                                               58477
# Memba                                                           57710
# Chiúre                                                          54989
# Lichinga, Chimbonila                                            54677
# Urbano 3 (KaMaxakeni)                                           54242
# Mueda, Muidumbe                                                 51418
# Massinga                                                        51294
# Nhamatanda                                                      50674
# Muecate, Nacaroa                                                49423
# Chibuto                                                         47458
# Chókwè                                                          47313
# Moatize                                                         46621
# Mutarara, Doa                                                   45900
# Namacurra                                                       45235
# Gorongosa, Maringué                                             45116
# Cuamba                                                          45048
# Ribáuè                                                          44206
# Namuno                                                          43571
# Manhiça                                                         40938
# Pebane                                                          40781
# Meconta                                                         40025
# Gilé                                                            39908
# Malema                                                          39652
# Tsangano                                                        39060
# Búzi                                                            38538
# Urbano 2 (Nlhamankulu)                                          38058
# Mecanhelas                                                      37691
# Mecubúri                                                        36864
# Urbano 1 (KaMpfumo), Urbano 6 (KaTembe), Urbano 7 (KaNyaka)     35258
# Cidade de Pemba                                                 34769
# Vilankulo                                                       33318
# Murrupula                                                       33075
# Mandimba                                                        32950
# Lugela                                                          32633
# Mogincual, Luipo                                                31984
# Barué                                                           31920
# Chinde, Luabo                                                   31279
# Sussundenga                                                     30970
# Morrumbene                                                      30824
# Caia                                                            28642
# Boane                                                           28554
# Ancuabe                                                         28172
# Namarroi                                                        27972
# Cidade de Maxixe                                                27879
# Marromeu                                                        27110
# Mecúfi, Metuge                                                  26608
# Homoine                                                         26156
# Mopeia                                                          26069
# Marracuene                                                      25909
# Chibabava                                                       24851
# Macanga                                                         24696
# Chifunde                                                        24103
# Mocímboa da Praia                                               23895
# Jangamo                                                         23085
# Guro, Macossa                                                   22921
# Marrupa, Mecula, Mavago                                         21911
# Macomia                                                         21820
# Marávia                                                         20456
# Lago                                                            19007
# Chicualacuala, Chigubo, Mapai, Massangena                       18800
# Guijá                                                           18566
# Lalaua                                                          18329
# Chiúta                                                          17400
# Nangade                                                         17143
# Cidade de Inhambane                                             16761
# Moamba                                                          15635
# Chemba                                                          15297
# N'gauma                                                         14626
# Sanga                                                           13624
# Magude                                                          13151
# Zumbo                                                           13134
# Palma                                                           13047
# Machanga                                                        12611
# Ibo, Quissanga                                                  12380
# Inhassoro                                                       12298
# Maúa                                                            12281
# Panda                                                           11342
# Mabote                                                          11073
# Namaacha                                                        10443
# Tambara                                                         10075
# Matutuine                                                        9845
# Funhalouro                                                       9218
# Cheringoma                                                       8700
# Govuro                                                           8478
# Nipepe                                                           8070
# Mabalane                                                         7664
# Metarica                                                         7383
# Massingir                                                        7255
# Majune                                                           6920
# Muembe                                                           6882
# Meluco                                                           6874
# Muanza                                                           6091
# Name: count, dtype: int64
# ------------------------------
# OWNERSHIP
# 1.0    3421165
# 0.0     302827
# Name: count, dtype: int64
# ------------------------------
# OWNERSHIPD
# Owned                           3421165
# Renting, not specified           168227
# Free/usufruct (no cash rent)     103704
# Not owned, other                  30896
# Name: count, dtype: int64
# ------------------------------
# ELECTRIC
# 0.0    4041795
# 1.0     889189
# Name: count, dtype: int64
# ------------------------------
# WATSUP
# No piped water                               3640110
# Have access to public piped water             476446
# Piped within the building or plot of land     277882
# Piped outside the dwelling                    246846
# Piped inside dwelling                         184469
# Piped, shared with other households           142673
# Name: count, dtype: int64
# ------------------------------
# PHONE
# 0.0    3679566
# 1.0      58295
# Name: count, dtype: int64
# ------------------------------
# AUTOS
# 0.0    3593375
# 1.0     144493
# Name: count, dtype: int64
# ------------------------------
# MOTORCYCLE
# 0.0    3522797
# 1.0     215058
# Name: count, dtype: int64
# ------------------------------
# BIKE
# 0.0    2463784
# 1.0    1274238
# Name: count, dtype: int64
# ------------------------------
# COMPUTER
# 0.0    3595161
# 1.0     142688
# Name: count, dtype: int64
# ------------------------------
# TV
# 0.0    3011095
# 1.0     726853
# Name: count, dtype: int64
# ------------------------------
# RADIO
# 0.0    2836450
# 1.0    2102255
# Name: count, dtype: int64
# ------------------------------
# ROOMS
# 2.0     1515366
# 3.0     1220870
# 1.0     1048157
# 4.0      991736
# 5.0      121725
# 6.0       36862
# 7.0       15567
# 8.0        8611
# 9.0        4741
# 10.0       2354
# 11.0        864
# 12.0        739
# 13.0        298
# 14.0        185
# 16.0        129
# 15.0         73
# 20.0         62
# 19.0         32
# 18.0         28
# 17.0         27
# Name: count, dtype: int64
# ------------------------------
# BEDROOMS
# 1.0     2185100
# 2.0     1778469
# 3.0      762002
# 4.0      198699
# 5.0       27334
# 6.0        9596
# 7.0        3486
# 8.0        1632
# 9.0         904
# 10.0        641
# 11.0        170
# 12.0        136
# 13.0        135
# 15.0         89
# 14.0         33
# Name: count, dtype: int64
# ------------------------------
# TOILET
# Non-flush, latrine                  2592756
# No toilet                           2017372
# Flush toilet                         246514
# Non-flush, other and unspecified     111748
# Name: count, dtype: int64
# ------------------------------
# FLOOR
# None/unfinished (earth)    2574150
# Cement                     1026515
# Tile                         74002
# Wood                         31925
# Other finished, n.e.c.       26724
# Marble                        4504
# Name: count, dtype: int64
# ------------------------------
# WALL
# Mud with wood/wattle                   1553736
# Adobe                                  1331018
# Reed, bamboo, or palm                   786251
# Cement blocks                           778457
# Brick                                   383205
# Wood, fibercement, zinc, or plywood      86253
# Other material                           46104
# Plastic sheeting, cardboard               3392
# Name: count, dtype: int64
# ------------------------------
# ROOF
# Thatch (straw, grass, leaves, palm, etc.)    3086620
# Zinc or tin                                  1613439
# Asbestos                                      123939
# Reinforced concrete (slab)                     84878
# Other, unspecified                             41758
# Tile, unspecified material                     11216
# Tile or cement                                  6566
# Name: count, dtype: int64
# ------------------------------
# HHTYPE
# Married/cohab couple with children               1940990
# Extended family, relatives only                  1871917
# Single-parent family                              531339
# Married/cohab couple, no children                 216327
# Composite household, family and non-relatives     156552
# One-person household                              136497
# Polygamous family                                  52350
# Non-family household                                8662
# Group quarters                                      3966
# Name: count, dtype: int64
# ------------------------------
# NFAMS
# 1    4807858
# 2     132914
# 3      20393
# 4       6256
# 5       2508
# 9       2272
# 6       1252
# 7        727
# 8        389
# Name: count, dtype: int64
# ------------------------------
# NCOUPLES
# 1    3480535
# 0    1332776
# 2     138336
# 3      18961
# 4       3345
# 5        424
# 6        150
# 7         42
# Name: count, dtype: int64
# ------------------------------
# NMOTHERS
# 1    3501726
# 0     847652
# 2     490631
# 3     102709
# 4      23427
# 5       5797
# 6       1722
# 7        558
# 8        215
# 9        132
# Name: count, dtype: int64
# ------------------------------
# NFATHERS
# 1    3184845
# 0    1655879
# 2     116947
# 3      14434
# 4       2100
# 5        257
# 6        107
# Name: count, dtype: int64
# ------------------------------
# RESIDENT
# Present resident    4813326
# Absent resident      161243
# Name: count, dtype: int64
# ------------------------------
# FAMSIZE
# 6     797051
# 5     777802
# 4     715336
# 3     579680
# 7     530128
# 8     387817
# 2     380761
# 9     258012
# 1     176081
# 10    126739
# 11     81638
# 12     54660
# 13     31805
# 14     21725
# 15     15035
# 16     11048
# 17      7748
# 18      6024
# 19      3305
# 20      2417
# 21      2216
# 22      1648
# 24      1102
# 23       950
# 25       866
# 26       532
# 27       531
# 28       355
# 29       317
# 31       262
# 30       145
# 32       122
# 47       115
# 36       108
# 35        99
# 34        84
# 33        81
# 44        64
# 38        63
# 41        33
# 39        32
# 37        30
# 45         2
# Name: count, dtype: int64
# ------------------------------
# NCHILD
# 0    3076451
# 1     548649
# 2     435727
# 3     349439
# 4     271527
# 5     151849
# 6      82687
# 7      36814
# 8      12715
# 9       8711
# Name: count, dtype: int64
# ------------------------------
# NCHLT5
# 0    3733472
# 1     766742
# 2     411546
# 3      55436
# 4       6195
# 5        876
# 6        196
# 7         67
# 8         27
# 9         12
# Name: count, dtype: int64
# ------------------------------
# ELDCH
# 6.0     94349
# 4.0     94241
# 10.0    92088
# 7.0     91551
# 12.0    91536
# 3.0     91229
# 5.0     88535
# 1.0     87841
# 2.0     86096
# 15.0    83005
# 8.0     79037
# 14.0    78694
# 9.0     78267
# 0.0     76894
# 13.0    76881
# 11.0    70720
# 17.0    69044
# 16.0    67240
# 18.0    61997
# 20.0    46728
# 19.0    45319
# 22.0    31422
# 21.0    30096
# 23.0    23490
# 25.0    20269
# 24.0    18808
# 27.0    13775
# 26.0    13532
# 28.0    11248
# 30.0    11039
# 29.0     9047
# 32.0     7458
# 50.0     6960
# 31.0     6330
# 35.0     5430
# 33.0     4682
# 34.0     4427
# 37.0     3782
# 36.0     3580
# 38.0     3126
# 40.0     3004
# 39.0     2833
# 42.0     2258
# 41.0     1943
# 45.0     1598
# 43.0     1546
# 47.0     1231
# 44.0     1116
# 46.0     1022
# 48.0      949
# 49.0      825
# Name: count, dtype: int64
# ------------------------------
# YNGCH
# 1.0     340385
# 0.0     312340
# 2.0     281722
# 3.0     185956
# 4.0     120694
# 5.0      86116
# 6.0      71136
# 7.0      62176
# 8.0      46788
# 10.0     43200
# 9.0      39176
# 12.0     35035
# 11.0     30510
# 13.0     27107
# 14.0     24245
# 15.0     23703
# 17.0     17690
# 16.0     17336
# 18.0     15761
# 20.0     11820
# 19.0     10988
# 22.0      8488
# 21.0      7812
# 23.0      7002
# 25.0      6740
# 50.0      5897
# 24.0      5638
# 27.0      4773
# 30.0      4604
# 26.0      4200
# 28.0      4182
# 32.0      3569
# 29.0      3515
# 35.0      2816
# 31.0      2621
# 33.0      2245
# 34.0      2233
# 37.0      2198
# 40.0      1832
# 38.0      1808
# 36.0      1782
# 39.0      1706
# 42.0      1443
# 45.0      1141
# 41.0      1101
# 43.0      1088
# 47.0       963
# 44.0       783
# 48.0       734
# 46.0       668
# 49.0       652
# Name: count, dtype: int64
# ------------------------------
# RELATE
# Child             1944423
# Head              1409094
# Spouse/partner     894538
# Other relative     687676
# Non-relative        38680
# Name: count, dtype: int64
# ------------------------------
# RELATED
# Biological child                            1420683
# Head                                        1409094
# Spouse/partner                               894538
# Child                                        447593
# Other relative, not elsewhere classified     365466
# Grandchild                                   236088
# Stepchild                                     59602
# Child-in-law                                  55774
# Non-relative                                  38680
# Parent                                        30348
# Adopted child                                 16545
# Name: count, dtype: int64
# ------------------------------
# AGE
# 6.0      212852
# 5.0      207195
# 7.0      201935
# 10.0     180738
# 8.0      172844
# 12.0     164929
# 9.0      159502
# 20.0     144781
# 18.0     135732
# 11.0     135146
# 13.0     134798
# 15.0     134714
# 14.0     130095
# 17.0     126037
# 22.0     118885
# 16.0     114370
# 19.0     113745
# 25.0     112804
# 23.0     104962
# 30.0     103746
# 27.0      95006
# 21.0      92060
# 28.0      89690
# 24.0      86548
# 32.0      84680
# 35.0      80191
# 29.0      75191
# 26.0      72099
# 37.0      68096
# 40.0      66939
# 38.0      59875
# 33.0      58416
# 31.0      56281
# 42.0      55593
# 39.0      55454
# 34.0      53039
# 45.0      52398
# 36.0      48506
# 47.0      46195
# 43.0      44122
# 50.0      41868
# 48.0      36635
# 41.0      36426
# 49.0      34056
# 52.0      33174
# 57.0      31046
# 44.0      30563
# 60.0      29323
# 46.0      28699
# 53.0      28501
# 55.0      28115
# 51.0      25788
# 54.0      22947
# 58.0      21651
# 67.0      21505
# 56.0      20779
# 62.0      19602
# 59.0      18940
# 65.0      18700
# 63.0      15945
# 70.0      14583
# 61.0      14036
# 64.0      13355
# 68.0      13215
# 69.0      10865
# 66.0      10323
# 77.0      10263
# 72.0      10130
# 75.0       9259
# 73.0       6897
# 71.0       6618
# 80.0       6334
# 78.0       6156
# 74.0       5569
# 76.0       5152
# 79.0       4566
# 87.0       3719
# 82.0       3660
# 85.0       3197
# 81.0       2654
# 83.0       2562
# 84.0       1969
# 90.0       1741
# 89.0       1662
# 86.0       1635
# 88.0       1418
# 100.0      1266
# 92.0        856
# 97.0        769
# 95.0        758
# 99.0        747
# 93.0        654
# 91.0        622
# 98.0        600
# 4.0         438
# 94.0        435
# 96.0        426
# 3.0         341
# 2.0         270
# 1.0         259
# 0.0         138
# Name: count, dtype: int64
# ------------------------------
# SEX
# 0    2602538
# 1    2372031
# Name: count, dtype: int64
# ------------------------------
# MARST
# Single/never married                2515729
# Married/in union                    2125606
# Widowed                              170740
# Separated/divorced/spouse absent     141489
# Name: count, dtype: int64
# ------------------------------
# MARSTD
# Single/never married     2515729
# Consensual union         1585606
# Married, formally         540000
# Widowed                   170740
# Separated or divorced     141489
# Name: count, dtype: int64
# ------------------------------
# CONSENS
# 1.0    1585606
# 0.0     540000
# Name: count, dtype: int64
# ------------------------------
# CHBORN
# 0.0     545234
# 1.0     227701
# 2.0     199973
# 3.0     164401
# 4.0     139676
# 5.0     106672
# 6.0      81570
# 7.0      58350
# 8.0      42209
# 9.0      27451
# 10.0     20374
# 11.0      9299
# 12.0      7295
# 13.0      2515
# 14.0       306
# 15.0       183
# 16.0        72
# 18.0        70
# 17.0        32
# Name: count, dtype: int64
# ------------------------------
# CHSURV
# 1.0     242341
# 2.0     216169
# 3.0     177025
# 4.0     146062
# 5.0     104424
# 6.0      71452
# 7.0      42596
# 8.0      22950
# 0.0      10295
# 9.0      10236
# 10.0      5119
# 11.0       545
# 12.0       249
# 14.0       146
# 13.0        55
# Name: count, dtype: int64
# ------------------------------
# CHBORNF
# 0.0     718540
# 1.0     343119
# 2.0     233687
# 3.0     145773
# 4.0      84442
# 5.0      44193
# 6.0      22086
# 7.0      10240
# 8.0       4403
# 9.0       1950
# 10.0       710
# 11.0       305
# 12.0       157
# 13.0        94
# Name: count, dtype: int64
# ------------------------------
# CHBORNM
# 0.0     716768
# 1.0     342715
# 2.0     235586
# 3.0     147755
# 4.0      85191
# 5.0      44219
# 6.0      20743
# 7.0       9342
# 8.0       4021
# 9.0       1643
# 10.0       631
# 11.0       275
# 12.0       109
# 13.0        85
# Name: count, dtype: int64
# ------------------------------
# CHSURVF
# 0.0     555751
# 1.0     362969
# 2.0     234901
# 3.0     133518
# 4.0      64613
# 5.0      26135
# 6.0       9292
# 7.0       3258
# 8.0        943
# 9.0        392
# 10.0       126
# 11.0       100
# 12.0        57
# Name: count, dtype: int64
# ------------------------------
# CHSURVM
# 0.0     562072
# 1.0     360847
# 2.0     235598
# 3.0     131908
# 4.0      63100
# 5.0      25398
# 6.0       8305
# 7.0       2823
# 8.0        758
# 9.0        308
# 12.0        99
# 10.0        98
# 11.0        62
# Name: count, dtype: int64
# ------------------------------
# BIRTHSLYR
# 0.0    838265
# 1.0    203290
# 2.0     10814
# 4.0     10166
# 3.0      4542
# Name: count, dtype: int64
# ------------------------------
# BIRTHSURV
# 0.0    549652
# 1.0    188009
# 2.0      9295
# 4.0      9216
# 3.0      4069
# Name: count, dtype: int64
# ------------------------------
# MORTMOT
# 0.0    3644336
# 1.0    1272711
# Name: count, dtype: int64
# ------------------------------
# MORTFAT
# 0.0    2303276
# 1.0    1384832
# Name: count, dtype: int64
# ------------------------------
# NATIVITY
# 1.0    4882291
# 0.0      77245
# Name: count, dtype: int64
# ------------------------------
# CITIZEN
# 1.0    4871670
# 0.0      32619
# Name: count, dtype: int64
# ------------------------------
# NATION
# Mozambique                      4871670
# Malawi                            13063
# South Africa                       4349
# Zimbabwe                           4200
# Other countries n.s.               2613
# Tanzania                           1918
# Portugal                           1543
# Zambia                              814
# Cape Verde                          808
# India                               564
# Lesotho                             304
# Congo (Republic of)                 228
# Africa, other or n.s.               200
# Pakistan                            192
# Europe, other or n.s.               178
# Democratic Republic of Congo        176
# Angola                              152
# Sao Tome and Principe               138
# Brazil                              122
# United Kingdom                       87
# China                                85
# Burundi                              84
# Italy                                84
# Nigeria                              74
# Guinea                               71
# Swaziland                            67
# Namibia                              53
# United States                        52
# Rwanda                               48
# Americas, other or n.s.              46
# Chile                                42
# Kenya                                35
# Sierra Leone                         33
# Cuba                                 32
# Spain                                28
# France                               27
# Senegal                              27
# Equatorial Guinea                    25
# Guinea-Bissau                        24
# Togo                                 22
# South America, other or n.s.          8
# Asia, other or n.s.                   3
# Name: count, dtype: int64
# ------------------------------
# BPL1_MZ
# Nampula             931347
# Zambézia            914003
# Tete                403426
# Cabo Delgado        394877
# Sofala              394864
# Inhambane           374163
# Gaza                349079
# Manica              292797
# Niassa              258465
# Maputo              207664
# Cidade de Maputo    202367
# Foreign Country      82526
# Name: count, dtype: int64
# ------------------------------
# BPL2_MZ
# Xai-Xai, Bilene, Mandlakazi, Limpopo, Chongoene                173059
# Milange, Molumbo                                               116571
# Quelimane, Inhassunge, Nicoadala                               114153
# Beira, Dondo                                                   109151
# Cidade de Nampula, Rapale                                      108527
# Cidade de Tete, Cahora-Bassa, Changara, Mágoè, Marara          103367
# Cidade da Matola                                                97497
# Gondola, Manica, Macate, Vanduzi                                86114
# Abroad                                                          82526
# Monapo, Nacala-à-Velha                                          82206
# Morrumbala, Derre                                               78729
# Angónia                                                         75532
# Ile, Mulevala                                                   72070
# Moma, Larde                                                     72067
# Angoche                                                         70769
# Ilha de Moçambique, Mossuril, Nacala-Porto                      69868
# Balama, Montepuez                                               68122
# Erati                                                           67549
# Chibuto                                                         66528
# Gúruè                                                           65307
# Massinga                                                        64190
# Maganja da Costa, Mocubela                                      64156
# Mogovolas                                                       63456
# Alto Molocué                                                    62727
# Inharrime, Zavala                                               62452
# Mocuba                                                          61295
# Memba                                                           61117
# Machaze, Mossurize                                              60428
# Chiúre                                                          56877
# Mutarara, Doa                                                   51241
# Mueda, Muidumbe                                                 50751
# Búzi                                                            49492
# Gorongosa, Maringué                                             47017
# Muecate, Nacaroa                                                46854
# Namacurra                                                       46257
# Murrupula                                                       46131
# Chimoio                                                         45601
# Ribáuè                                                          44474
# Chókwè                                                          44249
# Lichinga, Chimbonila                                            43345
# Namuno                                                          43071
# Moatize                                                         41777
# Vilankulo                                                       41361
# Pebane                                                          40674
# Manhiça                                                         40539
# Malema                                                          38649
# Gilé                                                            38628
# Mecubúri                                                        36182
# Chinde, Luabo                                                   35741
# Cuamba                                                          35655
# Mecanhelas                                                      33990
# Meconta                                                         33705
# Caia                                                            33342
# Morrumbene                                                      32989
# Lugela                                                          32449
# Tsangano                                                        31657
# Mogincual, Luipo                                                31147
# Nhamatanda                                                      28961
# Namarroi                                                        28627
# Chibabava                                                       28383
# Sussundenga                                                     28295
# Homoine                                                         27438
# Marromeu                                                        27172
# Ancuabe                                                         26052
# Jangamo                                                         25844
# Barué                                                           25424
# Guro, Macossa                                                   25343
# Mopeia                                                          24235
# Mandimba                                                        24231
# Mecúfi, Metuge                                                  23405
# Macomia                                                         21399
# Cidade de Pemba                                                 21347
# Marrupa, Mecula, Mavago                                         21219
# Mocímboa da Praia                                               20766
# Chemba                                                          20298
# Macanga                                                         20033
# Marávia                                                         19418
# Guijá                                                           19226
# Chiúta                                                          18717
# Lago                                                            18485
# Chicualacuala, Chigubo, Mapai, Massangena                       18364
# Chifunde                                                        17938
# Lalaua                                                          17726
# Cidade de Inhambane                                             17644
# Urbano 4 (KaMavota)                                             17591
# Cidade de Maxixe                                                17269
# Urbano 5 (KaMubukwana)                                          16990
# Marracuene                                                      16051
# Nangade                                                         15676
# Panda                                                           15364
# Machanga                                                        15171
# Maúa                                                            13999
# Magude                                                          13844
# Boane                                                           12576
# Mabote                                                          12321
# Sanga                                                           12216
# Zumbo                                                           12053
# Inhassoro                                                       11912
# N'gauma                                                         11909
# Ibo, Quissanga                                                  11894
# Tambara                                                         11516
# Funhalouro                                                      11169
# Urbano 3 (KaMaxakeni)                                           10943
# Palma                                                           10663
# Moamba                                                          10199
# Cheringoma                                                      10083
# Govuro                                                           9721
# Nipepe                                                           8858
# Majune                                                           8172
# Matutuine                                                        7558
# Metarica                                                         7441
# Urbano 2 (Nlhamankulu)                                           7015
# Meluco                                                           6885
# Mabalane                                                         6534
# Massingir                                                        6360
# Muembe                                                           6167
# Urbano 1 (KaMpfumo), Urbano 6 (KaTembe), Urbano 7 (KaNyaka)      5493
# Namaacha                                                         5298
# Muanza                                                           4803
# Name: count, dtype: int64
# ------------------------------
# RELIGION
# Christian      1957953
# Muslim          680720
# No religion     579155
# Other           253764
# Name: count, dtype: int64
# ------------------------------
# RELIGIOND
# Catholic (Roman or unspecified)    1027762
# Muslim                              680720
# No religion                         579155
# Zion Christian                      419660
# Other                               253764
# Anglican                             56745
# Name: count, dtype: int64
# ------------------------------
# RACE
# Black         4846058
# Mixed race      23756
# White            4487
# Indian           3696
# Other            1018
# Pakistani         660
# Chinese           138
# Name: count, dtype: int64
# ------------------------------
# SPEAKPORT
# 0.0    2621118
# 1.0    2300149
# Name: count, dtype: int64
# ------------------------------
# LANGMZ
# Emakhuwa                  974711
# Portuguese                552014
# Xitsonga or Xichangana    357904
# Other languages           347840
# Elomwe                    265897
# Sena                      264344
# Cinyanja                  214802
# Cindau                    148669
# Xitswa                    138538
# Echuwabo                  137445
# Cicopi                     53453
# Cinyungwe                  45013
# Ciyao                      33270
# Shimakonde                 26552
# Chitewe                    26025
# Xirhonga                   22154
# Bitonga or Gitonga         18423
# Cishona                    16492
# Cibalke                    11568
# Kimwani                     8001
# Coti                        6085
# Kiswahili                   2646
# Isizulo                      690
# Cinsenga                     476
# Isiswazi                     190
# Sena Care                     78
# Ekarungu                      77
# Citonga                       50
# Ciqwaka                       47
# Cingoni                       47
# Cindonje                      46
# Gombe                         41
# Tonga                         41
# Xilwandle                     38
# Cicewa                        35
# Ecocti                        34
# Merenje                       31
# Xikalanga                     30
# Phondzo                       25
# Xidzivi                       25
# Name: count, dtype: int64
# ------------------------------
# MTONGMZ
# Emakhuwa                  968009
# Portuguese                518383
# Other languages           374670
# Xitsonga or Xichangana    347977
# Sena                      273145
# Elomwe                    266141
# Cinyanja                  210703
# Cindau                    153724
# Echuwabo                  152932
# Xitswa                    149254
# Cinyungwe                  46209
# Ciyao                      34021
# Cichopi                    30762
# Shimakonde                 27562
# Chitewe                    25938
# Xirhonga                   23551
# Bitonga or Gitonga         22893
# Cishona                    17345
# Cibalke                    10699
# Kimwani                     7628
# Coti                        6028
# Kiswahili                   2169
# Isizulo                     1281
# Cinsenga                     495
# Isiswazi                     393
# Cikhambani                   143
# Cilenje                       76
# Ekarungu                      67
# Citonga                       64
# Sutho                         59
# Cingoni                       53
# Cindonje                      51
# Sena Care                     44
# Xikalanga                     42
# Merenje                       39
# Gombe                         37
# Phondzo                       37
# Cilambwe                      34
# Ciqwaka                       31
# Tonga                         27
# Xilwandle                     26
# Cicewa                        25
# Name: count, dtype: int64
# ------------------------------
# SCHOOL
# No, never attended          2021434
# No, attended in the past    1556987
# Yes                         1302991
# Name: count, dtype: int64
# ------------------------------
# LIT
# 0.0    2660373
# 1.0    2278409
# Name: count, dtype: int64
# ------------------------------
# EDATTAIN
# Less than primary completed    3962365
# Primary completed               813236
# Secondary completed             118858
# University completed             22838
# Name: count, dtype: int64
# ------------------------------
# EDATTAIND
# No schooling                            2334915
# Some primary completed                  1627450
# Primary (6 yrs) completed                619652
# Lower secondary general completed        185584
# Secondary, general track completed        94244
# University completed                      22838
# Secondary, technical track completed      18533
# Lower secondary technical completed        8000
# Some college completed                     6081
# Name: count, dtype: int64
# ------------------------------
# EMPSTAT
# Employed      2242927
# Inactive      2229226
# Unemployed      33884
# Name: count, dtype: int64
# ------------------------------
# EMPSTATD
# At work                                        2013998
# In school                                       977708
# Housework                                       723119
# Inactive, other reasons                         429958
# At work, family holding, not specified          128969
# Have job, not at work in reference period        97229
# Health reasons, unable to work, or disabled      78456
# Unemployed, new worker                           21003
# Retirees and living on rent                      19985
# Unemployed, experienced worker                   12881
# Armed forces                                      2731
# Name: count, dtype: int64
# ------------------------------
# LABFORCE
# 0.0    2041229
# 1.0    1207128
# Name: count, dtype: int64
# ------------------------------
# EMPSECT
# Individual/family enterprise, and self-employed        2030976
# Private, not elsewhere classified                       126026
# Public                                                   78564
# Mixed: public-private or parastatal                      16818
# Foreign government or non-governmental organization       5418
# Collective or cooperative                                 3207
# Name: count, dtype: int64
# ------------------------------
# OCCISCO
# Skilled agricultural and fishery workers      1731764
# Service workers and shop and market sales      185260
# Crafts and related trades workers              122327
# Elementary occupations                          82845
# Technicians and associate professionals         37735
# Plant and machine operators and assemblers      36503
# Professionals                                   25851
# Clerks                                          15716
# Legislators, senior officials and managers       8694
# Armed forces                                      992
# Name: count, dtype: int64
# ------------------------------
# INDGEN
# Agriculture, fishing, and forestry              1695731
# Wholesale and retail trade                       206217
# Manufacturing                                     63355
# Construction                                      45686
# Public administration and defense                 45273
# Transportation, storage, and communications       26843
# Education                                         24549
# Private household services                        21779
# Other services                                    16124
# Business services and real estate                 14601
# Mining and extraction                             14270
# Health and social work                            11527
# Hotels and restaurants                             7336
# Electricity, gas, water and waste management       2806
# Financial services and insurance                   2172
# Other industry, n.e.c.                              844
# Name: count, dtype: int64
# ------------------------------
# DISABLED
# 0.0    4830873
# 1.0     137609
# Name: count, dtype: int64
# ------------------------------
# DISEMP
# 0.0    3716691
# 1.0      78456
# Name: count, dtype: int64
# ------------------------------
# DISBLND
# 0.0    3722482
# 1.0      17301
# Name: count, dtype: int64
# ------------------------------
# DISDEAF
# 0.0    3725222
# 1.0      14561
# Name: count, dtype: int64
# ------------------------------
# DISMUTE
# 0.0    3679515
# 1.0       7149
# Name: count, dtype: int64
# ------------------------------
# DISLOWR
# 0.0    3712368
# 1.0      27415
# Name: count, dtype: int64
# ------------------------------
# DISUPPR
# 0.0    3730628
# 1.0       9155
# Name: count, dtype: int64
# ------------------------------
# DISMNTL
# 0.0    4953677
# 1.0      14805
# Name: count, dtype: int64
# ------------------------------
# DISORIG
# Disease                    50602
# Congenital, since birth    31805
# Other cause, n.e.c.         9543
# Work accident               6246
# Other                       5947
# Transport accident          4187
# War injury                  1017
# Multiple causes              773
# Name: count, dtype: int64
# ------------------------------
# mig_provincial
# 0.0    4746396
# 1.0     228173
# Name: count, dtype: int64
# ------------------------------

# %% [markdown]
# ### Crosstabs

# %%
len(mig5_data.columns)
mig5_data.columns.tolist()
# Out:
# ['YEAR',
#  'PERSONS',
#  'GQ',
#  'GQTYPE',
#  'UNREL',
#  'URBAN',
#  'POPDENSGEO1',
#  'POPDENSGEO2',
#  'GEO1_MZ',
#  'GEO2_MZ',
#  'OWNERSHIP',
#  'OWNERSHIPD',
#  'ELECTRIC',
#  'WATSUP',
#  'PHONE',
#  'AUTOS',
#  'MOTORCYCLE',
#  'BIKE',
#  'COMPUTER',
#  'TV',
#  'RADIO',
#  'ROOMS',
#  'BEDROOMS',
#  'TOILET',
#  'FLOOR',
#  'WALL',
#  'ROOF',
#  'HHTYPE',
#  'NFAMS',
#  'NCOUPLES',
#  'NMOTHERS',
#  'NFATHERS',
#  'RESIDENT',
#  'FAMSIZE',
#  'NCHILD',
#  'NCHLT5',
#  'ELDCH',
#  'YNGCH',
#  'RELATE',
#  'RELATED',
#  'AGE',
#  'SEX',
#  'MARST',
#  'MARSTD',
#  'CONSENS',
#  'CHBORN',
#  'CHSURV',
#  'CHBORNF',
#  'CHBORNM',
#  'CHSURVF',
#  'CHSURVM',
#  'BIRTHSLYR',
#  'BIRTHSURV',
#  'MORTMOT',
#  'MORTFAT',
#  'NATIVITY',
#  'CITIZEN',
#  'NATION',
#  'BPL1_MZ',
#  'BPL2_MZ',
#  'RELIGION',
#  'RELIGIOND',
#  'RACE',
#  'SPEAKPORT',
#  'LANGMZ',
#  'MTONGMZ',
#  'SCHOOL',
#  'LIT',
#  'EDATTAIN',
#  'EDATTAIND',
#  'EMPSTAT',
#  'EMPSTATD',
#  'LABFORCE',
#  'EMPSECT',
#  'OCCISCO',
#  'INDGEN',
#  'DISABLED',
#  'DISEMP',
#  'DISBLND',
#  'DISDEAF',
#  'DISMUTE',
#  'DISLOWR',
#  'DISUPPR',
#  'DISMNTL',
#  'DISORIG',
#  'mig_provincial']

# %%
pd.crosstab(mig5_data['YEAR'], mig5_data['mig_provincial'], normalize='index')
# max_diff = abs(tab[0] - tab[1]).max()
# print(max_diff)
# Out:
# mig_provincial       0.0       1.0
# YEAR
# 1997            0.891614  0.108386
# 2007            0.967314  0.032686
# 2017            0.980460  0.019540

# %%
useful_features = []
useless_features = []

for col in mig5_data.columns:
    if col == 'mig_provincial':
        continue
    if mig5_data[col].nunique() > 20:
        continue

    tab = pd.crosstab(mig5_data[col], mig5_data['mig_provincial'], normalize='index')
    max_diff = tab[1].max() - tab[1].min()
    mean_rate = tab[1].mean()
    if max_diff >= 0.02:
        useful_features.append({'feature': col, 'max_diff': round(max_diff, 4), 'mean_rate': round(mean_rate, 4)})
    else:
        useless_features.append({'feature': col, 'max_diff': round(max_diff, 4), 'mean_rate': round(mean_rate, 4)})

useful_df = pd.DataFrame(useful_features).sort_values(by="max_diff", ascending=False).reset_index(drop=True)
useless_df = pd.DataFrame(useless_features).sort_values(by="max_diff", ascending=False).reset_index(drop=True)

print("Top useful variables:")
print(useful_df.head(10))

print("\nSample of less useful variables:")
print(useless_df.head(10))
# Out:
# Top useful variables:
#     feature  max_diff  mean_rate
# 0    GQTYPE    0.4828     0.2988
# 1      RACE    0.4541     0.2005
# 2   BPL1_MZ    0.3662     0.0748
# 3  NATIVITY    0.3449     0.2127
# 4        GQ    0.3389     0.2158
# 5   CITIZEN    0.3150     0.2015
# 6     NFAMS    0.3078     0.1626
# 7     UNREL    0.3061     0.1563
# 8  EMPSTATD    0.2559     0.0701
# 9     ROOMS    0.2500     0.0840
#
# Sample of less useful variables:
#      feature  max_diff  mean_rate
# 0  RELIGIOND    0.0199     0.0256
# 1     SCHOOL    0.0196     0.0457
# 2   RELIGION    0.0157     0.0248
# 3     DISEMP    0.0135     0.0445
# 4       BIKE    0.0133     0.0230
# 5     MARSTD    0.0125     0.0439
# 6    DISMUTE    0.0122     0.0193
# 7  SPEAKPORT    0.0115     0.0462
# 8   ELECTRIC    0.0110     0.0486
# 9    DISMNTL    0.0110     0.0514

# %%
pd.crosstab(mig5_data['GQTYPE'], mig5_data['mig_provincial'], normalize='index')
# Out:
# mig_provincial                                           0.0       1.0
# GQTYPE
# 1-person unit created by splitting large household  0.732245  0.267755
# Boarding school or student housing                  0.627479  0.372521
# Floating population                                 0.870494  0.129506
# Hospital, nursing home, hospice, or instutions ...  0.913208  0.086792
# Hotel, pension, lodging, or boarding house          0.617647  0.382353
# Military or police institution                      0.430451  0.569549
# Other group quarters                                0.836406  0.163594
# Prisons, reformatories, or correctional institu...  0.500000  0.500000
# Religious institution, monastery, seminary, or ...  0.782895  0.217105

# %%
pd.crosstab(mig5_data['GQ'], mig5_data['mig_provincial'], normalize='index')
# Out:
# mig_provincial                                           0.0       1.0
# GQ
# 1-person unit created by splitting large household  0.732245  0.267755
# Households                                          0.954436  0.045564
# Institutions                                        0.615514  0.384486
# Other group quarters                                0.834476  0.165524

# %% [markdown]
# ### Process Migration Response
